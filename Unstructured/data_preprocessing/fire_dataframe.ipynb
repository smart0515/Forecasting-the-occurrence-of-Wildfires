# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('not_fire_final - 복사본.csv',index_col='Unnamed: 0')

# %%
data
# Out:
#         field1  field2          _X         _Y
# 0     20160721  100300  127.999027  37.876942
# 1     20160601  235300  127.668951  37.672071
# 2     20140221  185400  128.928300  37.360300
# 3     20180210   85500  127.950393  37.695306
# 4     20110219   24300  127.868326  37.813265
# ...        ...     ...         ...        ...
# 1048  20201102  114900  127.816577  37.590990
# 1049  20140228  202300  127.561279  37.713371
# 1050  20120207  184400  127.456764  38.053610
# 1051  20140223  183500  127.871023  37.591671
# 1052  20140228   93600  127.909490  37.619857
#
# [1053 rows x 4 columns]

# %% [markdown]
# ## 산불이 발생한 지점이 있는 파일 불러오기

# %%
import csv
import os

# 디렉토리 경로 설정
folder_path = "fire_loc/"

# 디렉토리 내 CSV 파일 목록 가져오기
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

# %% [markdown]
# ### 그 지점의 인덱스 추출

# %%
import os
import pandas as pd
import numpy as np

# 대상 폴더 경로 설정
folder_path = "fire_loc/"

# 결과를 저장할 리스트 초기화
list_i = []
list_j = []

# CSV 파일에서 값이 9999인 인덱스 찾기
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        filepath = os.path.join(folder_path, filename)
        df = pd.read_csv(filepath)
        df_9999 = df == 9999
        i_indices, j_indices = np.where(df_9999)
        list_i.extend(i_indices)
        list_j.extend(j_indices)

# 결과 출력
print(list_i)
print(list_j)
# Out:
# [145, 143, 216, 244, 147, 117, 255, 163, 193, 154, 72, 72, 167, 68, 219, 255, 90, 234, 96, 141, 244, 175, 181, 103, 140, 208, 76, 103, 214, 146, 76, 106, 90, 180, 61, 80, 84, 49, 76, 210, 90, 90, 180, 49, 93, 165, 85, 167, 141, 170, 145, 222, 90, 29, 69, 129, 90, 233, 139, 156, 69, 64, 165, 59, 194, 143, 167, 133, 72, 134, 246, 75, 181, 122, 107, 166, 75, 199, 153, 148, 236, 77, 181, 178, 162, 122, 232, 217, 68, 208, 136, 175, 84, 255, 58, 58, 209, 78, 236, 223, 153, 197, 85, 182, 157, 208, 167, 167, 251, 236, 90, 154, 194, 244, 246, 59, 72, 189, 194, 153, 231, 172, 123, 79, 82, 237, 216, 232, 119, 153, 155, 251, 144, 42, 121, 159, 72, 251, 84, 110, 155, 81, 196, 140, 92, 221, 86, 227, 267, 153, 122, 147, 254, 147, 210, 15, 165, 147, 79, 267, 141, 165, 160, 110, 173, 128, 151, 122, 219, 45, 85, 179, 175, 56, 170, 128, 224, 90, 155, 210, 141, 79, 175, 90, 130, 201, 76, 122, 223, 267, 155, 128, 158, 227, 106, 210, 201, 59, 92, 172, 263, 79, 241, 146, 102, 200, 153, 237, 153, 193, 156, 98, 257, 89, 62, 143, 234, 170, 229, 133, 150, 75, 162, 195, 252, 90, 179, 141, 128, 160, 85, 129, 213, 244, 15, 224, 141, 162, 75, 128, 89, 166, 217, 153, 167, 154, 85, 15, 75, 143, 150, 152, 237, 168, 67, 116, 244, 193, 128, 167, 121, 203, 89, 194, 244, 236, 233, 88, 15, 244, 90, 255, 109, 80, 237, 69, 191, 219, 92, 97, 221, 104, 217, 94, 125, 108, 106, 131, 68, 90, 170, 141, 91, 109, 85, 76,
, 186, 327, 175, 85, 238, 226, 310, 269, 160, 184, 139, 223, 226, 139, 43, 161, 121, 103, 374, 127, 329, 268, 181, 67, 248, 238, 150, 322, 137, 92, 145, 46, 261, 226, 196, 85, 242, 340, 188, 293, 119, 127, 160, 76, 244, 152, 183, 164, 335, 168, 101, 93, 138, 198, 195, 113, 166, 164, 36, 137, 242, 119, 329, 336, 147, 244, 198, 168, 132, 155, 281, 197, 129, 304, 146, 161, 152, 258, 291, 145, 90, 212, 366, 284, 298, 287, 125, 106, 297, 176, 128, 160, 132, 134, 120, 276, 55, 126, 339, 168, 137, 197, 126, 293, 127, 322, 182, 127, 273, 241, 310, 145, 242, 176, 339, 328, 341, 313, 92, 245, 258, 375, 175, 224, 118, 166, 46, 222, 240, 234, 130, 293, 239, 193, 297, 249, ...

# %%
data['i']=list_i

# %%
data['j']=list_j

# %%
data
# Out:
#         field1  field2          _X         _Y    i    j
# 0     20160721  100300  127.999027  37.876942  145  313
# 1     20160601  235300  127.668951  37.672071  143  310
# 2     20140221  185400  128.928300  37.360300  216  152
# 3     20180210   85500  127.950393  37.695306  244  139
# 4     20110219   24300  127.868326  37.813265  147  183
# ...        ...     ...         ...        ...  ...  ...
# 1048  20201102  114900  127.816577  37.590990   94  206
# 1049  20140228  202300  127.561279  37.713371   76   80
# 1050  20120207  184400  127.456764  38.053610  167  160
# 1051  20140223  183500  127.871023  37.591671  226  152
# 1052  20140228   93600  127.909490  37.619857  227  334
#
# [1053 rows x 6 columns]

# %% [markdown]
# ## 데이터프레임 크기에 맞게 구해둔 엑셀 경위도와 인덱스를 맵핑
# - 산불난 지점의 경위도를 찾을 수 있음

# %%
data_match=pd.read_csv('액셀경위도.csv')

# %%
data_match = data_match.rename(columns={'x': 'j', 'y': 'i'})

# %%
data_match.drop(['value'],axis=1,inplace=True)

# %%
data_match
# Out:
#           i    j         lon        lat
# 0         0    0  127.095038  38.613709
# 1         0    1  127.100714  38.613709
# 2         0    2  127.106391  38.613709
# 3         0    3  127.112067  38.613709
# 4         0    4  127.117744  38.613709
# ...     ...  ...         ...        ...
# 111195  277  395  129.337289  37.033537
# 111196  277  396  129.342965  37.033537
# 111197  277  397  129.348642  37.033537
# 111198  277  398  129.354318  37.033537
# 111199  277  399  129.359995  37.033537
#
# [111200 rows x 4 columns]

# %%
lon_list = []

for i_value, j_value in zip(list_i, list_j):
    try:
        result = data_match.loc[(data_match['i'] == i_value) & (data_match['j'] == j_value), 'lon'].values[0]
    except IndexError:
        result = None
        
    lon_list.append(result)

# %%
lat_list = []

for i_value, j_value in zip(list_i, list_j):
    try:
        result = data_match.loc[(data_match['i'] == i_value) & (data_match['j'] == j_value), 'lat'].values[0]
    except IndexError:
        result = None
        
    lat_list.append(result)

# %%
data['lon']=lon_list

# %%
data['lat']=lat_list

# %%
data
# Out:
#         field1  field2          _X         _Y    i    j         lon        lat
# 0     20160721  100300  127.999027  37.876942  145  313  128.871809  37.786543
# 1     20160601  235300  127.668951  37.672071  143  310  128.854779  37.797953
# 2     20140221  185400  128.928300  37.360300  216  152  127.957879  37.381517
# 3     20180210   85500  127.950393  37.695306  244  139  127.884083  37.221789
# 4     20110219   24300  127.868326  37.813265  147  183  128.133853  37.775134
# ...        ...     ...         ...        ...  ...  ...         ...        ...
# 1048  20201102  114900  127.816577  37.590990   94  206  128.264414  38.077478
# 1049  20140228  202300  127.561279  37.713371   76   80  127.549164  38.180160
# 1050  20120207  184400  127.456764  38.053610  167  160  128.003291  37.661042
# 1051  20140223  183500  127.871023  37.591671  226  152  127.957879  37.324471
# 1052  20140228   93600  127.909490  37.619857  227  334  128.991017  37.318767
#
# [1053 rows x 8 columns]

# %%
data.to_csv('fire_lon_lat.csv')

# %%
_df=pd.read_csv('fire_lon_lat.csv',index_col='Unnamed: 0')

# %%
_df
# Out:
#         field1  field2          _X         _Y    i    j         lon        lat
# 0     20160721  100300  127.999027  37.876942  145  313  128.871809  37.786543
# 1     20160601  235300  127.668951  37.672071  143  310  128.854779  37.797953
# 2     20140221  185400  128.928300  37.360300  216  152  127.957879  37.381517
# 3     20180210   85500  127.950393  37.695306  244  139  127.884083  37.221789
# 4     20110219   24300  127.868326  37.813265  147  183  128.133853  37.775134
# ...        ...     ...         ...        ...  ...  ...         ...        ...
# 1048  20201102  114900  127.816577  37.590990   94  206  128.264414  38.077478
# 1049  20140228  202300  127.561279  37.713371   76   80  127.549164  38.180160
# 1050  20120207  184400  127.456764  38.053610  167  160  128.003291  37.661042
# 1051  20140223  183500  127.871023  37.591671  226  152  127.957879  37.324471
# 1052  20140228   93600  127.909490  37.619857  227  334  128.991017  37.318767
#
# [1053 rows x 8 columns]

# %%
_df.drop(['field2','_X','_Y'],axis=1,inplace=True)

# %%
list_i=_df['i'].tolist()
list_j=_df['j'].tolist()

# %%
# csv 파일 리스트와 list_i, list_j 리스트를 저장한 변수들
csv_files = []
for i in range(1103):
    filename = f"data_set/fire_csv_data/humidity/{i:04d}.csv"
    csv_files.append(filename)

# 결과를 저장할 리스트
results_hum = []

# 반복문으로 csv 파일 하나씩 열어서 값을 찾아서 results 리스트에 저장
for csv_file, i, j in zip(csv_files, list_i, list_j):
    df = pd.read_csv(csv_file,index_col='Unnamed: 0') # csv 파일 열기
    value = df.iloc[i, j] # i행, j열의 값을 찾기
    results_hum.append(value) # 결과를 리스트에 추가

# %%
# csv 파일 리스트와 list_i, list_j 리스트를 저장한 변수들
csv_files = []
for i in range(1103):
    filename = f"data_set/fire_csv_data/rainfall//{i:04d}.csv"
    csv_files.append(filename)

# 결과를 저장할 리스트
results_rainfall = []

# 반복문으로 csv 파일 하나씩 열어서 값을 찾아서 results 리스트에 저장
for csv_file, i, j in zip(csv_files, list_i, list_j):
    df = pd.read_csv(csv_file,index_col='Unnamed: 0') # csv 파일 열기
    value = df.iloc[i, j] # i행, j열의 값을 찾기
    results_rainfall.append(value) # 결과를 리스트에 추가

# %%
# csv 파일 리스트와 list_i, list_j 리스트를 저장한 변수들
csv_files = []
for i in range(1103):
    filename = f"data_set/fire_csv_data/temp//{i:04d}.csv"
    csv_files.append(filename)

# 결과를 저장할 리스트
results_temp = []

# 반복문으로 csv 파일 하나씩 열어서 값을 찾아서 results 리스트에 저장
for csv_file, i, j in zip(csv_files, list_i, list_j):
    df = pd.read_csv(csv_file,index_col='Unnamed: 0') # csv 파일 열기
    value = df.iloc[i, j] # i행, j열의 값을 찾기
    results_temp.append(value) # 결과를 리스트에 추가

# %%
# csv 파일 리스트와 list_i, list_j 리스트를 저장한 변수들
csv_files = []
for i in range(1103):
    filename = f"data_set/fire_csv_data/wind speed//{i:04d}.csv"
    csv_files.append(filename)

# 결과를 저장할 리스트
results_wind = []

# 반복문으로 csv 파일 하나씩 열어서 값을 찾아서 results 리스트에 저장
for csv_file, i, j in zip(csv_files, list_i, list_j):
    df = pd.read_csv(csv_file,index_col='Unnamed: 0') # csv 파일 열기
    value = df.iloc[i, j] # i행, j열의 값을 찾기
    results_wind.append(value) # 결과를 리스트에 추가

# %%
_df
# Out:
#         field1    i    j         lon        lat
# 0     20160721  145  313  128.871809  37.786543
# 1     20160601  143  310  128.854779  37.797953
# 2     20140221  216  152  127.957879  37.381517
# 3     20180210  244  139  127.884083  37.221789
# 4     20110219  147  183  128.133853  37.775134
# ...        ...  ...  ...         ...        ...
# 1048  20201102   94  206  128.264414  38.077478
# 1049  20140228   76   80  127.549164  38.180160
# 1050  20120207  167  160  128.003291  37.661042
# 1051  20140223  226  152  127.957879  37.324471
# 1052  20140228  227  334  128.991017  37.318767
#
# [1053 rows x 5 columns]

# %%
_df['습도']=results_hum
_df['강수']=results_rainfall
_df['기온']=results_temp
_df['풍속']=results_wind

# %% [markdown]
# ## 경위도에 맞는 기상값을 맵핑하였음
# - 기상값은 idw 보간을 통하여 구함

# %%
_df
# Out:
#         field1    i    j         lon        lat         습도        강수  \
# 0     20160721  145  313  128.871809  37.786543  40.128791  0.000000
# 1     20160601  143  310  128.854779  37.797953  54.952699  0.000000
# 2     20140221  216  152  127.957879  37.381517  23.066370  0.000000
# 3     20180210  244  139  127.884083  37.221789  46.988972  0.012152
# 4     20110219  147  183  128.133853  37.775134  56.415674  0.000000
# ...        ...  ...  ...         ...        ...        ...       ...
# 1048  20201102   94  206  128.264414  38.077478  72.982431  0.018083
# 1049  20140228   76   80  127.549164  38.180160  31.472493  0.000000
# 1050  20120207  167  160  128.003291  37.661042  72.069482  0.000000
# 1051  20140223  226  152  127.957879  37.324471  23.018648  0.000000
# 1052  20140228  227  334  128.991017  37.318767  49.096944  0.000000
#
#              기온        풍속
# 0     -2.467752  3.945949
# 1      1.049347  1.936912
# 2     13.431703  1.434781
# 3     -6.417820  1.834428
# 4      1.448924  2.580111
# ...         ...       ...
# 1048   7.762557  3.856538
# 1049  12.683992  2.840163
# 1050   7.687654  0.620234
# 1051  20.798500  3.076569
# 1052  22.399174  2.298449
#
# [1053 rows x 9 columns]

# %%
# _df에서 32767이 하나라도 있는 열을 찾아서 해당 열의 모든 행 삭제
mask = (_df == 32767).any(axis=1)
_df = _df[~mask]

# %%
_df['발생시간']=999
_df['날씨']='없음'
_df['특보내용']='없음'
_df['target']=0

# %%
_df.to_csv('structed_fire_data.csv',encoding='cp949')
