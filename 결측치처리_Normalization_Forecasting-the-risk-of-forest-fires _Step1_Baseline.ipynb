# %%
from pycaret.classification import *

# %%
import numpy as np
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'


from tqdm import tqdm
from tqdm.auto import tqdm
import warnings
warnings.filterwarnings(action='ignore')

import seaborn as sns 
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib.ticker as ticker
from IPython.display import set_matplotlib_formats

sns.set(style='white', context='notebook', palette='deep')
line_color = ['#FFBF00','#FF7F50','#DE3163','#9FE2BF','#40E0D0','#6495ED','#117A65','#2471A3','#CCCCFF','#8E44AD','#CD5C5C' ,'#F08080','#FA8072' ,'#E9967A' ,'#FFA07A']
plt.style.use('fivethirtyeight')
plt.style.use("seaborn-whitegrid")
plt.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False
print(plt.rcParams['font.family'])
# %matplotlib inline
# Out:
# ['Malgun Gothic']

# %% [markdown]
# # 데이터 불러오기

# %%
data=pd.read_csv('산불_전체기상데이터_정규화.csv',encoding='utf-8',index_col=0)

# %%
data['발생지역'].unique()
# Out:
# array(['KB', 'GW', 'KN', 'JN', 'GG', 'CN', 'JB', 'CB', 'SE'], dtype=object)

# %%
data.head()
# Out:
#       년   월   일 발생지역   지점  피해면적  평균기온(°C)  평균 풍속(m/s)  일강수량(mm)  상대습도  \
# 0  2022   5  31   KB  992  5.30  1.071246    0.118464 -0.269151  39.4
# 1  2022   4  18   KB  992  0.03  0.299490   -0.138252 -0.269151  33.3
# 2  2022  10  19   KB  992  0.01 -0.472266   -0.394968 -0.269151  56.9
# 3  2022  12  20   KB  992  0.16 -1.645335   -0.822828 -0.269151  61.8
# 4  2022   4  20   KB  991  3.18  0.443551    0.631896 -0.269151  35.5
#
#         실효습도  계절
# 0  35.771319   봄
# 1  35.766492   봄
# 2  49.668174  기타
# 3  45.023499  가을
# 4  29.199069   봄

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10011 entries, 0 to 10010
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   년           10011 non-null  int64
#  1   월           10011 non-null  int64
#  2   일           10011 non-null  int64
#  3   발생지역        10011 non-null  object
#  4   지점          10011 non-null  int64
#  5   피해면적        10011 non-null  float64
#  6   평균기온(°C)    10011 non-null  float64
#  7   평균 풍속(m/s)  10011 non-null  float64
#  8   일강수량(mm)    10011 non-null  float64
#  9   상대습도        9368 non-null   float64
#  10  실효습도        9345 non-null   float64
#  11  계절          10011 non-null  object
# dtypes: float64(6), int64(4), object(2)
# memory usage: 1016.7+ KB

# %%
data['년']=data['년'].astype(str)
data['월']=data['월'].astype(str)
data['일']=data['일'].astype(str)

# %%
data['날짜']=data['년']+data['월']+data['일']

# %%
data['날짜']=pd.to_datetime(data['날짜'],format='%Y%m%d')

# %%
data.head(1)
# Out:
#       년  월   일 발생지역   지점  피해면적  평균기온(°C)  평균 풍속(m/s)  일강수량(mm)  상대습도  \
# 0  2022  5  31   KB  992   5.3  1.071246    0.118464 -0.269151  39.4
#
#         실효습도 계절         날짜
# 0  35.771319  봄 2022-05-31

# %%
data.columns
# Out:
# Index(['년', '월', '일', '발생지역', '지점', '피해면적', '평균기온(°C)', '평균 풍속(m/s)',
#        '일강수량(mm)', '상대습도', '실효습도', '계절', '날짜'],
#       dtype='object')

# %%
data.drop(['년','월','일','지점','계절'],axis=1,inplace=True)

# %%
data.head()
# Out:
#   발생지역  피해면적  평균기온(°C)  평균 풍속(m/s)  일강수량(mm)  상대습도       실효습도         날짜
# 0   KB  5.30  1.071246    0.118464 -0.269151  39.4  35.771319 2022-05-31
# 1   KB  0.03  0.299490   -0.138252 -0.269151  33.3  35.766492 2022-04-18
# 2   KB  0.01 -0.472266   -0.394968 -0.269151  56.9  49.668174 2022-10-19
# 3   KB  0.16 -1.645335   -0.822828 -0.269151  61.8  45.023499 2022-12-20
# 4   KB  3.18  0.443551    0.631896 -0.269151  35.5  29.199069 2022-04-20

# %%
data['날짜']=pd.to_datetime(data['날짜'])
data[['계절']]=np.nan

# %%
for i in range(2001, 2023):
    data.loc[(f"{i}-02-01" <= data['날짜']) & (data['날짜'] <= f"{i}-05-15"), '계절']=data.loc[(f"{i}-02-01" <= data['날짜']) & (data['날짜'] <= f"{i}-05-15"), '계절'].fillna('봄')
    data.loc[(f"{i}-11-01" <= data['날짜']) & (data['날짜'] <= f"{i}-12-15"), '계절']=data.loc[(f"{i}-11-01" <= data['날짜']) & (data['날짜'] <= f"{i}-12-15"), '계절'].fillna('가을')
data[['계절']]=data[['계절']].fillna('그외')

# %%
import datetime
data['month'] = data['날짜'].dt.strftime('%m')

# %% [markdown]
# **발생지역별 월 평균을 구해서 결측값을 채우기위해 groupby 사용**

# %%
data.groupby(['발생지역','month']).mean()
data.groupby(['발생지역','month']).mean()[['상대습도']]
# Out:
#                  피해면적  평균기온(°C)  평균 풍속(m/s)  일강수량(mm)       상대습도       실효습도
# 발생지역 month
# CB   01      0.451250 -1.396323    0.304924 -0.280083  54.125000  46.540925
#      02      1.475000 -1.018276    0.143988 -0.275974  52.681034  44.579490
#      03      0.414277 -0.455692    0.389696 -0.266197  46.742000  41.375533
#      04      1.625079  0.087467    0.309617 -0.262966  44.729379  39.778734
#      05      0.538500  0.591024    0.053500 -0.263807  51.239623  42.789024
#      06      0.580571  1.031992   -0.050226 -0.280083  52.802857  46.709153
#      07      0.090000  1.310001   -0.320816 -0.280083  63.583333  54.657386
#      08      0.018000  1.270793    0.003892 -0.280083  64.520000  52.354081
#      09      0.247143  0.750567   -0.146865 -0.280083  64.542857  54.991598
#      10      0.153333  0.011029   -0.621472 -0.280083  61.011111  53.725956
#      11      0.278000 -0.779510    0.283502 -0.229133  57.835714  50.985871
#      12      0.358333 -1.332569   -0.125390 -0.280083  56.820000  47.113939
# CN   01      0.293636 -1.456381   -0.638961 -0.269448  60.870000  52.289713
#      02      0.647375 -1.072394   -0.348198 -0.266133  52.897222  46.996696
#      03      0.566750 -0.533266   -0.147148 -0.260828  53.108791  46.127555
#      04      1.882284  0.020571    0.005466 -0.229834  50.586692  44.800696
#      05      0.280000  0.594799   -0.218452 -0.267923  53.548148  46.641562
#      06      0.276863  1.016600   -0.203613 -0.259047  62.234783  53.403778
#      07      0.095714  1.361383    0.055260 -0.269448  61.200000  57.644209
#      08      0.565455  1.509084    0.138567 -0.189080  69.200000  59.867919
#      09      0.206538  0.779563   -0.245629 -0.269448  62.400000  54.445745
#      10      0.060000  0.226272   -0.194297 -0.266848  67.971429  56.664291
#      11      0.448333 -0.576071   -0.151207 -0.263554  60.344444  52.748126
#      12      0.148214 -1.180214   -0.390199 -0.258397  65.074074  54.332177
# GG   01      0.144375 -1.564776   -0.357281 -0.230354  55.512903  46.961223
#      02      0.226429 -1.119138   -0.037001 -0.238075  50.982456  45.308149
#      03      0.419098 -0.497430   -0.006019 -0.242787  51.457862  44.896858
#      04      0.497707  0.020923    0.062167 -0.211078  49.437400  43.784688
#      05      0.260071  0.519094   -0.016606 -0.214976  53.678226  46.320242
#      06      0.244390  0.968496   -0.181329 -0.240432  54.810811  46.895884
#      07      0.086154  1.339630   -0.081737 -0.234005  65.007692  55.714102
#      08      0.186667  1.427660   -0.094529 -0.245401  65.572727  55.532623
#      09      0.179655  0.810785   -0.225504 -0.214748  61.876923  54.781118
#      10      0.132286  0.125221   -0.272612 -0.173440  65.209091  54.168946
#      11      0.804455 -0.779758   -0.280718 -0.238433  59.067742  51.062329
#      12      0.209674 -1.242099   -0.064451 -0.218830  54.952273  47.992267
# GW   01      5.271818 -1.158772    0.552341 -0.263493  46.103226  38.761538
#      02      3.516762 -1.072106    0.196057 -0.245027  47.843158  40.013465
#      03     28.580145 -0.371210    0.213795 -0.260995  43.504145  39.384782
#      04     17.183859  0.194934    0.228067 -0.248622  45.252518  40.072060
#      05      5.807251  0.655872    0.087307 -0.233372  49.722751  43.852405
#      06      0.221132  1.069386   -0.120970 -0.177114  56.613402  47.997972
#      07      0.243750  1.379698   -0.243640 -0.263493  64.085714  53.830282
#      08      0.816000  1.434030    0.105467 -0.192158  64.646154  54.738124
#      09      0.065556  0.618804   -0.278307 -0.263493  65.425000  57.118474
#      10      0.244490  0.202353   -0.451011 -0.257631  67.302326  56.297181
#      11      0.845196 -0.814870    0.096473 -0.231106  53.603061  45.076981
#      12      1.467558 -1.166108    0.395860 -0.259318  49.814634  42.466844
# JB   01      0.142000 -1.536631   -0.817751 -0.278098  56.140000  46.259199
#      02      0.579492 -0.985666   -0.203165 -0.274045  57.822034  50.102339
#      03      0.510788 -0.513811   -0.135856 -0.213839  53.278344  46.865591
#      04      2.636970  0.018605   -0.070362 -0.221006  52.162434  45.150865
#      05      0.327419  0.454162   -0.049446 -0.233738  53.916949  47.021520
#      06      0.261304  0.990438   -0.196482 -0.278098  61.795652  52.828101
#      07      0.115000  1.525823   -0.270409 -0.278098  61.500000  55.641604
#      08      0.204286  1.580274   -0.046013 -0.278098  63.514286  53.337497
#      09      0.131111  0.843132   -0.401757 -0.264812  65.462500  55.523261
#      10      0.388261  0.229896   -0.278154 -0.253836  67.771429  59.276101
#      11      0.576316 -0.625497   -0.371832 -0.252924  64.566667  54.078089
#      12      0.202381 -1.340705   -0.422320 -0.274302  60.204762  51.445502
# JN   01      1.799412 -1.435200   -0.204609 -0.268793  60.112500  49.837470
#      02      0.772158 -1.086567    0.023954 -0.261116  53.585276  46.568113
#      03      0.605673 -0.690197   -0.061474 -0.247147  54.329221  47.145603
#      04      1.494664 -0.150484   -0.216809 -0.244214  53.060484  46.324760
#      05      0.376667  0.421794   -0.258557 -0.233473  53.978431  47.552690
#      06      0.298438  0.906174   -0.308061 -0.208023  67.266667  57.774067
#      07      0.040000  1.446660   -0.791342 -0.268793  76.900000  63.176563
#      08      0.177273  1.452403   -0.393695 -0.268793  74.044444  61.336210
#      09      0.705333  0.867664   -0.220327 -0.268793  65.720000  58.398565
#      10      0.633846  0.169120   -0.245105 -0.268793  68.326667  57.033261
#      11      0.368431 -0.827918   -0.025897 -0.262926  58.295349  50.669710
#      12      0.522639 -1.309266   -0.064609 -0.264637  57.026154  48.665348
# KB   01      1.136044 -1.400521    0.299952 -0.266313  44.522222  38.242864
#      02      4.101063 -1.120257    0.229977 -0.256612  45.325316  39.225530
#      03     38.607738 -0.451267    0.262891 -0.263698  44.017536  38.919001
#      04      9.173333  0.065114    0.107883 -0.239069  43.914930  38.778497
#      05      3.233878  0.626305    0.101000 -0.243019  50.606417  44.051110
#      06      0.509286  0.968427   -0.054717 -0.236017  57.838525  48.391173
#      07      0.175625  1.581892   -0.138252 -0.239561  69.887500  58.811139
#      08      1.839474  1.542965   -0.070695 -0.251029  64.326316  54.390117
#      09      0.158095  0.777244   -0.256423 -0.230210  66.190000  56.956613
#      10      0.157600  0.034418   -0.468560 -0.249353  65.461702  55.736957
#      11      0.496441 -0.933401    0.029024 -0.249941  53.641765  45.197986
#      12      0.369658 -1.368208    0.285505 -0.257359  47.594815  40.342436
# KN   01      1.181604 -1.486909    0.098868 -0.264785  42.600000  35.473507
#      02      3.419444 -1.179100    0.009222 -0.258449  42.692063  36.354751
#      03      3.350000 -0.568223    0.108407 -0.262576  46.870886  40.940123
#      04      2.260590 -0.047811    0.032021 -0.240962  48.517241  42.180534
#      05      6.299541  0.580211   -0.063152 -0.231688  55.064423  46.686688
#      06      0.177286  1.006836   -0.255526 -0.197773  59.957143  50.828168
#      07      0.433333  1.698597   -0.386216 -0.265740  65.900000  59.325453
#      08      0.274286  1.513214   -0.108746 -0.265740  69.192857  58.644127
#      09      0.060625  0.809122   -0.422131 -0.265740  67.181250  57.236027
#      10      0.151562  0.092127   -0.248661 -0.263631  60.242623  50.354643
#      11      0.215542 -0.941363   -0.159960 -0.259438  50.223313  43.697397
#      12      0.432939 -1.392904    0.003028 -0.259376  44.857965  38.987464
# SE   01      0.124000 -1.430295   -0.288153 -0.245920  43.980000  40.404191
#      02      0.036207 -1.108895   -0.201567 -0.238807  47.227586  41.864554
#      03      0.113960 -0.524701    0.317092 -0.245920  45.518812  40.542254
#      04      0.056933  0.130764    0.205388 -0.145527  44.624000  38.412321
#      05      0.079231  0.598427   -0.193242 -0.212861  53.607692  43.456381
#      06      0.185217  0.946695   -0.079217 -0.190611  51.260870  43.145440
#      07      0.090000  1.100070   -0.850963 -0.245920  74.300000  57.430560
#      09      0.010000  0.604294   -0.526265 -0.245920  65.800000  56.962794
#      10      0.090000 -0.108044   -0.557189 -0.245920  48.514286  43.680710
#      11      0.030000 -0.738722   -0.196647 -0.244357  51.295455  44.835677
#      12      0.028182 -1.242732   -0.354077 -0.236544  46.672727  39.886149
#                  상대습도
# 발생지역 month
# CB   01     54.125000
#      02     52.681034
#      03     46.742000
#      04     44.729379
#      05     51.239623
#      06     52.802857
#      07     63.583333
#      08     64.520000
#      09     64.542857
#      10     61.011111
#      11     57.835714
#      12     56.820000
# CN   01     60.870000
#      02     52.897222
#      03     53.108791
#      04     50.586692
#      05     53.548148
#      06     62.234783
#      07     61.200000
#      08     69.200000
#      09     62.400000
#      10     67.971429
#      11     60.344444
#      12     65.074074
# GG   01     55.512903
#      02     50.982456
#      03     51.457862
#      04     49.437400
#      05     53.678226
#      06     54.810811
#      07     65.007692
#      08     65.572727
#      09     61.876923
#      10     65.209091
#      11     59.067742
#      12     54.952273
# GW   01     46.103226
#      02     47.843158
#      03     43.504145
#      04     45.252518
#      05     49.722751
#      06     56.613402
#      07     64.085714
#      08     64.646154
#      09     65.425000
#      10     67.302326
#      11     53.603061
#      12     49.814634
# JB   01     56.140000
#      02     57.822034
#      03     53.278344
#      04     52.162434
#      05     53.916949
#      06     61.795652
#      07     61.500000
#      08     63.514286
#      09     65.462500
#      10     67.771429
#      11     64.566667
#      12     60.204762
# JN   01     60.112500
#      02     53.585276
#      03     54.329221
#      04     53.060484
#      05     53.978431
#      06     67.266667
#      07     76.900000
#      08     74.044444
#      09     65.720000
#      10     68.326667
#      11     58.295349
#      12     57.026154
# KB   01     44.522222
#      02     45.325316
#      03     44.017536
#      04     43.914930
#      05     50.606417
#      06     57.838525
#      07     69.887500
#      08     64.326316
#      09     66.190000
#      10     65.461702
#      11     53.641765
#      12     47.594815
# KN   01     42.600000
#      02     42.692063
#      03     46.870886
#      04     48.517241
#      05     55.064423
#      06     59.957143
#      07     65.900000
#      08     69.192857
#      09     67.181250
#      10     60.242623
#      11     50.223313
#      12     44.857965
# SE   01     43.980000
#      02     47.227586
#      03     45.518812
#      04     44.624000
#      05     53.607692
#      06     51.260870
#      07     74.300000
#      09     65.800000
#      10     48.514286
#      11     51.295455
#      12     46.672727

# %%
cols=data.columns.drop(['피해면적', '평균기온(°C)', '평균 풍속(m/s)', '일강수량(mm)','계절','날짜','발생지역','month'])
cols
# Out:
# Index(['상대습도', '실효습도'], dtype='object')

# %%
cnt=0
for i in tqdm(range(len(cols))):
    for j in range(len(data)):
        if(np.isnan(data[[cols[i]]].loc[j].values[0])):  # 해당 컬럼의 값이 결측값이면 
            loc=data.loc[j]['발생지역']
            month=data.loc[j]['month']
            tmp=data.groupby(['발생지역','month']).mean()[[cols[i]]].loc[loc].loc[month].values[0]
            print(loc,month)
            print(tmp)
            cnt=cnt+1
            data[cols[i]].loc[j]=tmp

            print(data[[cols[i]]].loc[j])
print(cnt)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# KB 04
# 43.91492957746479
# 상대습도    43.91493
# Name: 5, dtype: float64
# GG 05
# 53.67822580645161
# 상대습도    53.678226
# Name: 65, dtype: float64
# KN 04
# 48.51724137931034
# 상대습도    48.517241
# Name: 627, dtype: float64
# KN 10
# 60.24262295081967
# 상대습도    60.242623
# Name: 703, dtype: float64
# KN 04
# 48.51724137931034
# 상대습도    48.517241
# Name: 706, dtype: float64
# KN 02
# 42.69206349206349
# 상대습도    42.692063
# Name: 707, dtype: float64
# JN 03
# 54.32922077922078
# 상대습도    54.329221
# Name: 709, dtype: float64
# KN 02
# 42.69206349206349
# 상대습도    42.692063
# Name: 711, dtype: float64
# KN 01
# 42.6
# 상대습도    42.6
# Name: 716, dtype: float64
# KN 04
# 48.51724137931035
# 상대습도    48.517241
# Name: 755, dtype: float64
# KN 05
# 55.06442307692308
# 상대습도    55.064423
# Name: 777, dtype: float64
# KN 04
# 48.51724137931035
# 상대습도    48.517241
# Name: 786, dtype: float64
# KN 10
# 60.24262295081967
# 상대습도    60.242623
# Name: 787, dtype: float64
# KN 05
# 55.06442307692308
# 상대습도    55.064423
# Name: 917, dtype: float64
# KN 12
# 44.85796460176991
# 상대습도    44.857965
# Name: 922, dtype: float64
# KN 03
# 46.87088607594937
# 상대습도    46.870886
# Name: 924, dtype: float64
# KN 12
# 44.85796460176991
# 상대습도    44.857965
# Name: 927, dtype: float64
# KN 02
# 42.69206349206349
# 상대습도    42.692063
# Name: 945, dtype: float64
# KN 02
# 42.6920634920635
# 상대습도    42.692063
# Name: 956, dtype: float64
# KN 02
# 42.69206349206349
# 상대습도    42.692063
# Name: 990, dtype: float64
# KN 05
# 55.06442307692308
# 상대습도    55.064423
# Name: 1001, dtype: float64
# KN 01
# 42.6
# 상대습도    42.6
# Name: 1003, dtype: float64
# KN 02
# 42.6920634920635
# 상대습도    42.692063
# Name: 1018, dtype: float64
# KN 04
# 48.51724137931034
# 상대습도    48.517241
# Name: 1019, dtype: float64
# KN 11
# 50.22331288343558
# 상대습도    50.223313
# Name: 1035, dtype: float64
# KN 04
# 48.51724137931034
# 상대습도    48.517241
# Name: 1036, dtype: float64
# KN 02
# 42.69206349206349
# 상대습도    42.692063
# Name: 1037, dtype: float64
# KN 04
# 48.51724137931035
# 상대습도    48.517241
# Name: 1043, dtype: float64
# JN 02
# 53.58527607361963
# 상대습도    53.585276
# Name: 1380, dtype: float64
# KN 04
# 48.51724137931034
# 상대습도    48.517241
# Name: 1382, dtype: float64
# KN 11
# 50.22331288343558
# 상대습도    50.223313
# Name: 1383, dtype: float64
# KN 01
# 42.599999999999994
# 상대습도    42.6
# Name: 1384, dtype: float64
# JN 11
# 58.295348837209296
# 상대습도    58.295349
# Name: 1386, dtype: float64
# KN 11
# 50.22331288343558
# 상대습도    50.223313
# Name: 1387, dtype: float64
# KN 03
# 46.870886075949365
# 상대습도    46.870886
# Name: 1388, dtype: float64
# KN 01
# 42.6
# 상대습도    42.6
# Name: 1390, dtype: float64
# KN 04
# 48.51724137931034
# 상대습도    48.517241
# Name: 1395, dtype: float64
# KN 02
# 42.6920634920635
# 상대습도    42.692063
# Name: 1398, dtype: float64
# KN 02
# 42.69206349206349
# 상대습도    42.692063
# Name: 1426, dtype: float64
# KN 10
# 60.24262295081967
# 상대습도    60.242623
# Name: 1431, dtype: float64
# KN 05
# 55.06442307692308
# 상대습도    55.064423
# Name: 1432, dtype: float64
# KN 03
# 46.870886075949365
# 상대습도    46.870886
# Name: 1453, dtype: float64
# KN 03
# 46.870886075949365
# 상대습도    46.870886
# Name: 1454, dtype: float64
# KN 05
# 55.06442307692308
# 상대습도    55.064423
# Name: 1563, dtype: float64
# KN 04
# 48.51724137931035
# 상대습도    48.517241
# Name: 1568, dtype: float64
# JN 12
# 57.026153846153846
# 상대습도    57.026154
# Name: 1745, dtype: float64
# JN 11
# 58.2953488372093
# 상대습도    58.295349
# Name: 1754, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 1758, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 1759, dtype: float64
# JN 03
# 54.32922077922078
# 상대습도    54.329221
# Name: 1761, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 1762, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 1764, dtype: float64
# KB 03
# 44.0175355450237
# 상대습도    44.017536
# Name: 1911, dtype: float64
# KB 03
# 44.0175355450237
# 상대습도    44.017536
# Name: 1914, dtype: float64
# KB 05
# 50.60641711229946
# 상대습도    50.606417
# Name: 1918, dtype: float64
# KB 06
# 57.838524590163935
# 상대습도    57.838525
# Name: 1943, dtype: float64
# KB 03
# 44.0175355450237
# 상대습도    44.017536
# Name: 1953, dtype: float64
# KB 03
# 44.01753554502369
# 상대습도    44.017536
# Name: 2133, dtype: float64
# KB 05
# 50.60641711229947
# 상대습도    50.606417
# Name: 2141, dtype: float64
# KB 02
# 45.3253164556962
# 상대습도    45.325316
# Name: 2144, dtype: float64
# KB 02
# 45.3253164556962
# 상대습도    45.325316
# Name: 2145, dtype: float64
# KB 05
# 50.60641711229947
# 상대습도    50.606417
# Name: 2152, dtype: float64
# KB 05
# 50.60641711229947
# 상대습도    50.606417
# Name: 2153, dtype: float64
# KB 12
# 47.59481481481482
# 상대습도    47.594815
# Name: 2155, dtype: float64
# KB 02
# 45.3253164556962
# 상대습도    45.325316
# Name: 2245, dtype: float64
# KB 02
# 45.3253164556962
# 상대습도    45.325316
# Name: 2250, dtype: float64
# KB 04
# 43.91492957746479
# 상대습도    43.91493
# Name: 2262, dtype: float64
# KB 12
# 47.59481481481481
# 상대습도    47.594815
# Name: 2268, dtype: float64
# KB 04
# 43.91492957746479
# 상대습도    43.91493
# Name: 2347, dtype: float64
# KB 03
# 44.01753554502369
# 상대습도    44.017536
# Name: 2353, dtype: float64
# KB 03
# 44.0175355450237
# 상대습도    44.017536
# Name: 2354, dtype: float64
# KB 04
# 43.91492957746479
# 상대습도    43.91493
# Name: 2369, dtype: float64
# KB 04
# 43.91492957746479
# 상대습도    43.91493
# Name: 2371, dtype: float64
# KB 02
# 45.325316455696196
# 상대습도    45.325316
# Name: 2650, dtype: float64
# KB 02
# 45.3253164556962
# 상대습도    45.325316
# Name: 2654, dtype: float64
# KB 03
# 44.0175355450237
# 상대습도    44.017536
# Name: 2656, dtype: float64
# KB 12
# 47.59481481481481
# 상대습도    47.594815
# Name: 2657, dtype: float64
# KB 03
# 44.0175355450237
# 상대습도    44.017536
# Name: 2661, dtype: float64
# KB 02
# 45.3253164556962
# 상대습도    45.325316
# Name: 2665, dtype: float64
# KB 03
# 44.01753554502369
# 상대습도    44.017536
# Name: 2677, dtype: float64
# KB 02
# 45.3253164556962
# 상대습도    45.325316
# Name: 2683, dtype: float64
# KB 02
# 45.3253164556962
# 상대습도    45.325316
# Name: 2688, dtype: float64
# KB 03
# 44.0175355450237
# 상대습도    44.017536
# Name: 2690, dtype: float64
# KB 10
# 65.46170212765956
# 상대습도    65.461702
# Name: 2693, dtype: float64
# KB 12
# 47.59481481481482
# 상대습도    47.594815
# Name: 3092, dtype: float64
# KB 02
# 45.3253164556962
# 상대습도    45.325316
# Name: 3094, dtype: float64
# KB 02
# 45.3253164556962
# 상대습도    45.325316
# Name: 3095, dtype: float64
# KB 04
# 43.91492957746479
# 상대습도    43.91493
# Name: 3097, dtype: float64
# KB 02
# 45.325316455696196
# 상대습도    45.325316
# Name: 3103, dtype: float64
# KB 11
# 53.64176470588235
# 상대습도    53.641765
# Name: 3105, dtype: float64
# KB 11
# 53.64176470588236
# 상대습도    53.641765
# Name: 3118, dtype: float64
# KB 12
# 47.59481481481482
# 상대습도    47.594815
# Name: 3364, dtype: float64
# KB 11
# 53.64176470588236
# 상대습도    53.641765
# Name: 3369, dtype: float64
# KB 02
# 45.3253164556962
# 상대습도    45.325316
# Name: 3371, dtype: float64
# KB 03
# 44.0175355450237
# 상대습도    44.017536
# Name: 3374, dtype: float64
# KB 03
# 44.0175355450237
# 상대습도    44.017536
# Name: 3375, dtype: float64
# KB 05
# 50.60641711229946
# 상대습도    50.606417
# Name: 3379, dtype: float64
# KB 04
# 43.91492957746478
# 상대습도    43.91493
# Name: 3387, dtype: float64
# KB 10
# 65.46170212765958
# 상대습도    65.461702
# Name: 3389, dtype: float64
# KB 12
# 47.59481481481481
# 상대습도    47.594815
# Name: 3390, dtype: float64
# KB 12
# 47.59481481481482
# 상대습도    47.594815
# Name: 3391, dtype: float64
# KB 02
# 45.3253164556962
# 상대습도    45.325316
# Name: 3395, dtype: float64
# KB 04
# 43.91492957746479
# 상대습도    43.91493
# Name: 3397, dtype: float64
# KB 11
# 53.64176470588236
# 상대습도    53.641765
# Name: 3398, dtype: float64
# KB 06
# 57.838524590163935
# 상대습도    57.838525
# Name: 3399, dtype: float64
# JB 04
# 52.162433862433865
# 상대습도    52.162434
# Name: 3402, dtype: float64
# KB 04
# 43.91492957746479
# 상대습도    43.91493
# Name: 3406, dtype: float64
# KB 04
# 43.91492957746479
# 상대습도    43.91493
# Name: 3407, dtype: float64
# KB 03
# 44.01753554502369
# 상대습도    44.017536
# Name: 3408, dtype: float64
# KB 12
# 47.59481481481482
# 상대습도    47.594815
# Name: 3411, dtype: float64
# KB 12
# 47.59481481481481
# 상대습도    47.594815
# Name: 3416, dtype: float64
# KB 04
# 43.91492957746479
# 상대습도    43.91493
# Name: 3494, dtype: float64
# KB 11
# 53.64176470588236
# 상대습도    53.641765
# Name: 3496, dtype: float64
# KB 06
# 57.83852459016393
# 상대습도    57.838525
# Name: 3498, dtype: float64
# KB 03
# 44.0175355450237
# 상대습도    44.017536
# Name: 3595, dtype: float64
# KB 03
# 44.0175355450237
# 상대습도    44.017536
# Name: 3596, dtype: float64
# KB 04
# 43.91492957746479
# 상대습도    43.91493
# Name: 3598, dtype: float64
# KB 03
# 44.0175355450237
# 상대습도    44.017536
# Name: 3606, dtype: float64
# KB 05
# 50.60641711229946
# 상대습도    50.606417
# Name: 3608, dtype: float64
# KB 06
# 57.838524590163935
# 상대습도    57.838525
# Name: 3610, dtype: float64
# KB 02
# 45.3253164556962
# 상대습도    45.325316
# Name: 3611, dtype: float64
# KB 04
# 43.91492957746479
# 상대습도    43.91493
# Name: 3612, dtype: float64
# KB 05
# 50.60641711229947
# 상대습도    50.606417
# Name: 3621, dtype: float64
# KB 09
# 66.19
# 상대습도    66.19
# Name: 3622, dtype: float64
# KB 01
# 44.522222222222226
# 상대습도    44.522222
# Name: 3627, dtype: float64
# KB 05
# 50.60641711229947
# 상대습도    50.606417
# Name: 3632, dtype: float64
# KB 05
# 50.60641711229947
# 상대습도    50.606417
# Name: 3633, dtype: float64
# KB 10
# 65.46170212765958
# 상대습도    65.461702
# Name: 3634, dtype: float64
# KB 12
# 47.59481481481482
# 상대습도    47.594815
# Name: 3636, dtype: float64
# KB 04
# 43.91492957746479
# 상대습도    43.91493
# Name: 3647, dtype: float64
# KB 04
# 43.91492957746479
# 상대습도    43.91493
# Name: 3648, dtype: float64
# KB 12
# 47.59481481481482
# 상대습도    47.594815
# Name: 3653, dtype: float64
# KB 03
# 44.01753554502369
# 상대습도    44.017536
# Name: 3654, dtype: float64
# KB 03
# 44.0175355450237
# 상대습도    44.017536
# Name: 3658, dtype: float64
# JN 10
# 68.32666666666667
# 상대습도    68.326667
# Name: 3677, dtype: float64
# JN 02
# 53.58527607361963
# 상대습도    53.585276
# Name: 3678, dtype: float64
# JN 11
# 58.295348837209296
# 상대습도    58.295349
# Name: 3679, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 3736, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 3821, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 3823, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 3827, dtype: float64
# JN 03
# 54.32922077922078
# 상대습도    54.329221
# Name: 3910, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 3911, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 3918, dtype: float64
# JN 02
# 53.58527607361963
# 상대습도    53.585276
# Name: 3926, dtype: float64
# JN 11
# 58.2953488372093
# 상대습도    58.295349
# Name: 3928, dtype: float64
# JN 05
# 53.97843137254902
# 상대습도    53.978431
# Name: 3929, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 3932, dtype: float64
# JN 02
# 53.58527607361963
# 상대습도    53.585276
# Name: 3938, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 3940, dtype: float64
# JN 12
# 57.026153846153846
# 상대습도    57.026154
# Name: 3942, dtype: float64
# JN 10
# 68.32666666666667
# 상대습도    68.326667
# Name: 3984, dtype: float64
# JN 02
# 53.58527607361963
# 상대습도    53.585276
# Name: 3988, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 4022, dtype: float64
# JN 03
# 54.32922077922078
# 상대습도    54.329221
# Name: 4024, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 4029, dtype: float64
# JN 02
# 53.58527607361963
# 상대습도    53.585276
# Name: 4031, dtype: float64
# JN 11
# 58.295348837209296
# 상대습도    58.295349
# Name: 4032, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 4034, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 4036, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 4037, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 4038, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 4043, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 4049, dtype: float64
# JN 02
# 53.58527607361963
# 상대습도    53.585276
# Name: 4051, dtype: float64
# JB 10
# 67.77142857142857
# 상대습도    67.771429
# Name: 4363, dtype: float64
# JB 03
# 53.27834394904459
# 상대습도    53.278344
# Name: 4364, dtype: float64
# JB 05
# 53.91694915254237
# 상대습도    53.916949
# Name: 4365, dtype: float64
# JN 06
# 67.26666666666667
# 상대습도    67.266667
# Name: 4397, dtype: float64
# JN 02
# 53.58527607361963
# 상대습도    53.585276
# Name: 4402, dtype: float64
# JN 04
# 53.06048387096774
# 상대습도    53.060484
# Name: 4404, dtype: float64
# JN 04
# 53.06048387096774
# 상대습도    53.060484
# Name: 4405, dtype: float64
# JN 04
# 53.06048387096774
# 상대습도    53.060484
# Name: 4409, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 4410, dtype: float64
# JN 04
# 53.06048387096774
# 상대습도    53.060484
# Name: 4411, dtype: float64
# JN 03
# 54.32922077922078
# 상대습도    54.329221
# Name: 4442, dtype: float64
# JN 05
# 53.978431372549025
# 상대습도    53.978431
# Name: 4472, dtype: float64
# JN 04
# 53.06048387096774
# 상대습도    53.060484
# Name: 4474, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 4514, dtype: float64
# JN 04
# 53.06048387096774
# 상대습도    53.060484
# Name: 4515, dtype: float64
# JN 04
# 53.06048387096774
# 상대습도    53.060484
# Name: 4516, dtype: float64
# JN 02
# 53.58527607361964
# 상대습도    53.585276
# Name: 4517, dtype: float64
# JN 09
# 65.72
# 상대습도    65.72
# Name: 4518, dtype: float64
# JN 08
# 74.04444444444444
# 상대습도    74.044444
# Name: 4519, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 4520, dtype: float64
# JB 03
# 53.27834394904458
# 상대습도    53.278344
# Name: 4552, dtype: float64
# JB 04
# 52.162433862433865
# 상대습도    52.162434
# Name: 4555, dtype: float64
# JB 11
# 64.56666666666666
# 상대습도    64.566667
# Name: 4593, dtype: float64
# JB 11
# 64.56666666666666
# 상대습도    64.566667
# Name: 4594, dtype: float64
# JB 04
# 52.16243386243386
# 상대습도    52.162434
# Name: 4598, dtype: float64
# JB 03
# 53.27834394904458
# 상대습도    53.278344
# Name: 4599, dtype: float64
# JB 10
# 67.77142857142857
# 상대습도    67.771429
# Name: 4600, dtype: float64
# JB 04
# 52.16243386243386
# 상대습도    52.162434
# Name: 4601, dtype: float64
# JB 03
# 53.27834394904458
# 상대습도    53.278344
# Name: 4604, dtype: float64
# JB 04
# 52.162433862433865
# 상대습도    52.162434
# Name: 4606, dtype: float64
# JB 04
# 52.162433862433865
# 상대습도    52.162434
# Name: 4607, dtype: float64
# JB 03
# 53.27834394904459
# 상대습도    53.278344
# Name: 4610, dtype: float64
# JN 02
# 53.58527607361964
# 상대습도    53.585276
# Name: 4723, dtype: float64
# JN 04
# 53.06048387096774
# 상대습도    53.060484
# Name: 4729, dtype: float64
# JB 03
# 53.27834394904459
# 상대습도    53.278344
# Name: 4759, dtype: float64
# JB 03
# 53.27834394904458
# 상대습도    53.278344
# Name: 4762, dtype: float64
# JN 05
# 53.978431372549025
# 상대습도    53.978431
# Name: 4768, dtype: float64
# JN 11
# 58.2953488372093
# 상대습도    58.295349
# Name: 4808, dtype: float64
# JN 11
# 58.295348837209296
# 상대습도    58.295349
# Name: 4810, dtype: float64
# JN 02
# 53.58527607361964
# 상대습도    53.585276
# Name: 4811, dtype: float64
# JN 09
# 65.72
# 상대습도    65.72
# Name: 4812, dtype: float64
# JN 03
# 54.32922077922078
# 상대습도    54.329221
# Name: 4813, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 4814, dtype: float64
# JN 04
# 53.06048387096774
# 상대습도    53.060484
# Name: 4816, dtype: float64
# JB 05
# 53.916949152542365
# 상대습도    53.916949
# Name: 4821, dtype: float64
# JB 04
# 52.16243386243386
# 상대습도    52.162434
# Name: 4822, dtype: float64
# JB 04
# 52.162433862433865
# 상대습도    52.162434
# Name: 4823, dtype: float64
# JB 11
# 64.56666666666666
# 상대습도    64.566667
# Name: 4824, dtype: float64
# JB 03
# 53.27834394904458
# 상대습도    53.278344
# Name: 4825, dtype: float64
# JN 10
# 68.32666666666667
# 상대습도    68.326667
# Name: 4830, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 4831, dtype: float64
# JN 09
# 65.72
# 상대습도    65.72
# Name: 4832, dtype: float64
# JN 12
# 57.026153846153846
# 상대습도    57.026154
# Name: 4833, dtype: float64
# JN 08
# 74.04444444444445
# 상대습도    74.044444
# Name: 4834, dtype: float64
# JN 03
# 54.32922077922078
# 상대습도    54.329221
# Name: 4835, dtype: float64
# JN 01
# 60.1125
# 상대습도    60.1125
# Name: 4836, dtype: float64
# JN 11
# 58.2953488372093
# 상대습도    58.295349
# Name: 4837, dtype: float64
# JN 10
# 68.32666666666667
# 상대습도    68.326667
# Name: 4838, dtype: float64
# JN 10
# 68.32666666666667
# 상대습도    68.326667
# Name: 4839, dtype: float64
# JN 03
# 54.32922077922078
# 상대습도    54.329221
# Name: 4841, dtype: float64
# JN 02
# 53.585276073619625
# 상대습도    53.585276
# Name: 4842, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 4846, dtype: float64
# JN 02
# 53.585276073619625
# 상대습도    53.585276
# Name: 4847, dtype: float64
# JN 03
# 54.32922077922078
# 상대습도    54.329221
# Name: 4849, dtype: float64
# JN 03
# 54.32922077922078
# 상대습도    54.329221
# Name: 4850, dtype: float64
# JN 10
# 68.32666666666667
# 상대습도    68.326667
# Name: 4851, dtype: float64
# JN 09
# 65.72
# 상대습도    65.72
# Name: 4853, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 4854, dtype: float64
# JN 03
# 54.32922077922078
# 상대습도    54.329221
# Name: 4855, dtype: float64
# JN 10
# 68.32666666666667
# 상대습도    68.326667
# Name: 4856, dtype: float64
# JN 06
# 67.26666666666667
# 상대습도    67.266667
# Name: 4857, dtype: float64
# JN 04
# 53.06048387096774
# 상대습도    53.060484
# Name: 4858, dtype: float64
# JN 04
# 53.06048387096774
# 상대습도    53.060484
# Name: 4859, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 4860, dtype: float64
# JN 10
# 68.32666666666667
# 상대습도    68.326667
# Name: 4861, dtype: float64
# JN 02
# 53.58527607361963
# 상대습도    53.585276
# Name: 4864, dtype: float64
# JN 02
# 53.58527607361963
# 상대습도    53.585276
# Name: 4865, dtype: float64
# JN 10
# 68.32666666666667
# 상대습도    68.326667
# Name: 4866, dtype: float64
# JN 03
# 54.32922077922078
# 상대습도    54.329221
# Name: 4867, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 4868, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 4870, dtype: float64
# JN 02
# 53.58527607361963
# 상대습도    53.585276
# Name: 4871, dtype: float64
# JN 12
# 57.026153846153846
# 상대습도    57.026154
# Name: 4873, dtype: float64
# JN 02
# 53.58527607361963
# 상대습도    53.585276
# Name: 4876, dtype: float64
# JN 03
# 54.32922077922078
# 상대습도    54.329221
# Name: 4877, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 4885, dtype: float64
# JN 02
# 53.58527607361963
# 상대습도    53.585276
# Name: 4889, dtype: float64
# JN 02
# 53.58527607361963
# 상대습도    53.585276
# Name: 4890, dtype: float64
# JN 02
# 53.58527607361963
# 상대습도    53.585276
# Name: 4897, dtype: float64
# JN 02
# 53.58527607361963
# 상대습도    53.585276
# Name: 4898, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 4906, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 4908, dtype: float64
# JN 12
# 57.026153846153846
# 상대습도    57.026154
# Name: 4910, dtype: float64
# JN 12
# 57.026153846153846
# 상대습도    57.026154
# Name: 4911, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 4949, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 4951, dtype: float64
# JN 03
# 54.32922077922078
# 상대습도    54.329221
# Name: 4953, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 4955, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 4956, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 4958, dtype: float64
# JN 02
# 53.58527607361963
# 상대습도    53.585276
# Name: 4966, dtype: float64
# JN 03
# 54.32922077922078
# 상대습도    54.329221
# Name: 4968, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 4975, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 5015, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 5016, dtype: float64
# JN 03
# 54.32922077922078
# 상대습도    54.329221
# Name: 5017, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 5020, dtype: float64
# JN 10
# 68.32666666666667
# 상대습도    68.326667
# Name: 5021, dtype: float64
# CB 02
# 52.68103448275862
# 상대습도    52.681034
# Name: 5111, dtype: float64
# JB 09
# 65.4625
# 상대습도    65.4625
# Name: 5112, dtype: float64
# JB 11
# 64.56666666666666
# 상대습도    64.566667
# Name: 5113, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 5130, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 5133, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 5134, dtype: float64
# GW 05
# 49.72275132275132
# 상대습도    49.722751
# Name: 5319, dtype: float64
# GW 06
# 56.61340206185567
# 상대습도    56.613402
# Name: 5320, dtype: float64
# GW 05
# 49.72275132275133
# 상대습도    49.722751
# Name: 5322, dtype: float64
# GW 05
# 49.72275132275132
# 상대습도    49.722751
# Name: 5323, dtype: float64
# GW 05
# 49.72275132275132
# 상대습도    49.722751
# Name: 5324, dtype: float64
# GW 03
# 43.5041450777202
# 상대습도    43.504145
# Name: 5325, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 5326, dtype: float64
# GW 03
# 43.5041450777202
# 상대습도    43.504145
# Name: 5327, dtype: float64
# GW 09
# 65.425
# 상대습도    65.425
# Name: 5328, dtype: float64
# GW 02
# 47.84315789473685
# 상대습도    47.843158
# Name: 5329, dtype: float64
# GG 03
# 51.45786163522012
# 상대습도    51.457862
# Name: 5354, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 5358, dtype: float64
# GG 04
# 49.437400000000004
# 상대습도    49.4374
# Name: 5366, dtype: float64
# GG 05
# 53.678225806451614
# 상대습도    53.678226
# Name: 5372, dtype: float64
# GG 11
# 59.06774193548387
# 상대습도    59.067742
# Name: 5378, dtype: float64
# GG 02
# 50.98245614035088
# 상대습도    50.982456
# Name: 5379, dtype: float64
# CN 08
# 69.2
# 상대습도    69.2
# Name: 5440, dtype: float64
# CN 08
# 69.19999999999999
# 상대습도    69.2
# Name: 5441, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 5451, dtype: float64
# GG 01
# 55.51290322580645
# 상대습도    55.512903
# Name: 5452, dtype: float64
# GG 04
# 49.4374
# 상대습도    49.4374
# Name: 5454, dtype: float64
# GG 06
# 54.810810810810814
# 상대습도    54.810811
# Name: 5455, dtype: float64
# GG 10
# 65.20909090909092
# 상대습도    65.209091
# Name: 5456, dtype: float64
# GG 04
# 49.4374
# 상대습도    49.4374
# Name: 5457, dtype: float64
# GW 06
# 56.613402061855666
# 상대습도    56.613402
# Name: 5458, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 5459, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 5460, dtype: float64
# GW 03
# 43.50414507772021
# 상대습도    43.504145
# Name: 5461, dtype: float64
# GW 05
# 49.72275132275132
# 상대습도    49.722751
# Name: 5462, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 5463, dtype: float64
# GW 06
# 56.613402061855666
# 상대습도    56.613402
# Name: 5464, dtype: float64
# GW 04
# 45.252517985611505
# 상대습도    45.252518
# Name: 5465, dtype: float64
# GW 05
# 49.72275132275133
# 상대습도    49.722751
# Name: 5466, dtype: float64
# GW 02
# 47.84315789473684
# 상대습도    47.843158
# Name: 5467, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 5468, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 5469, dtype: float64
# GW 05
# 49.72275132275132
# 상대습도    49.722751
# Name: 5470, dtype: float64
# GW 05
# 49.72275132275132
# 상대습도    49.722751
# Name: 5471, dtype: float64
# GW 10
# 67.30232558139535
# 상대습도    67.302326
# Name: 5472, dtype: float64
# CN 02
# 52.89722222222222
# 상대습도    52.897222
# Name: 5496, dtype: float64
# CN 09
# 62.4
# 상대습도    62.4
# Name: 5497, dtype: float64
# CN 11
# 60.34444444444444
# 상대습도    60.344444
# Name: 5498, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 5499, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 5500, dtype: float64
# GG 03
# 51.45786163522012
# 상대습도    51.457862
# Name: 5520, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 5521, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 5522, dtype: float64
# GG 09
# 61.87692307692308
# 상대습도    61.876923
# Name: 5523, dtype: float64
# GG 09
# 61.87692307692308
# 상대습도    61.876923
# Name: 5524, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 5731, dtype: float64
# CN 03
# 53.1087912087912
# 상대습도    53.108791
# Name: 5998, dtype: float64
# GG 06
# 54.810810810810814
# 상대습도    54.810811
# Name: 5999, dtype: float64
# GG 08
# 65.57272727272726
# 상대습도    65.572727
# Name: 6000, dtype: float64
# GG 12
# 54.95227272727273
# 상대습도    54.952273
# Name: 6004, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 6005, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 6091, dtype: float64
# GG 12
# 54.95227272727273
# 상대습도    54.952273
# Name: 6092, dtype: float64
# GG 03
# 51.45786163522012
# 상대습도    51.457862
# Name: 6093, dtype: float64
# CN 11
# 60.34444444444444
# 상대습도    60.344444
# Name: 6094, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 6095, dtype: float64
# GG 05
# 53.678225806451614
# 상대습도    53.678226
# Name: 6096, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 6097, dtype: float64
# CN 03
# 53.1087912087912
# 상대습도    53.108791
# Name: 6098, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 6099, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 6100, dtype: float64
# CN 11
# 60.34444444444444
# 상대습도    60.344444
# Name: 6101, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 6104, dtype: float64
# CN 02
# 52.897222222222226
# 상대습도    52.897222
# Name: 6108, dtype: float64
# CN 03
# 53.10879120879121
# 상대습도    53.108791
# Name: 6110, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 6113, dtype: float64
# CN 05
# 53.548148148148144
# 상대습도    53.548148
# Name: 6114, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 6116, dtype: float64
# CN 02
# 52.89722222222222
# 상대습도    52.897222
# Name: 6120, dtype: float64
# CN 03
# 53.10879120879121
# 상대습도    53.108791
# Name: 6121, dtype: float64
# CN 03
# 53.10879120879121
# 상대습도    53.108791
# Name: 6122, dtype: float64
# CN 03
# 53.10879120879121
# 상대습도    53.108791
# Name: 6126, dtype: float64
# CN 08
# 69.2
# 상대습도    69.2
# Name: 6127, dtype: float64
# CN 05
# 53.54814814814815
# 상대습도    53.548148
# Name: 6130, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 6135, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 6140, dtype: float64
# CN 10
# 67.97142857142858
# 상대습도    67.971429
# Name: 6144, dtype: float64
# CN 10
# 67.97142857142858
# 상대습도    67.971429
# Name: 6145, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 6146, dtype: float64
# CN 05
# 53.548148148148144
# 상대습도    53.548148
# Name: 6148, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 6149, dtype: float64
# CN 04
# 50.58669201520913
# 상대습도    50.586692
# Name: 6151, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 6156, dtype: float64
# CN 03
# 53.10879120879121
# 상대습도    53.108791
# Name: 6160, dtype: float64
# CN 03
# 53.1087912087912
# 상대습도    53.108791
# Name: 6161, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 6162, dtype: float64
# CN 03
# 53.1087912087912
# 상대습도    53.108791
# Name: 6168, dtype: float64
# CN 09
# 62.4
# 상대습도    62.4
# Name: 6169, dtype: float64
# CN 02
# 52.89722222222222
# 상대습도    52.897222
# Name: 6171, dtype: float64
# CN 02
# 52.89722222222222
# 상대습도    52.897222
# Name: 6173, dtype: float64
# CN 01
# 60.870000000000005
# 상대습도    60.87
# Name: 6174, dtype: float64
# CN 12
# 65.07407407407408
# 상대습도    65.074074
# Name: 6175, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 6204, dtype: float64
# CN 02
# 52.897222222222226
# 상대습도    52.897222
# Name: 6224, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 6225, dtype: float64
# CN 06
# 62.23478260869565
# 상대습도    62.234783
# Name: 6226, dtype: float64
# CN 06
# 62.234782608695646
# 상대습도    62.234783
# Name: 6227, dtype: float64
# CN 06
# 62.234782608695646
# 상대습도    62.234783
# Name: 6228, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 6229, dtype: float64
# CN 10
# 67.97142857142858
# 상대습도    67.971429
# Name: 6232, dtype: float64
# CN 07
# 61.2
# 상대습도    61.2
# Name: 6243, dtype: float64
# CN 07
# 61.199999999999996
# 상대습도    61.2
# Name: 6246, dtype: float64
# CB 03
# 46.742000000000004
# 상대습도    46.742
# Name: 6325, dtype: float64
# CB 04
# 44.72937853107344
# 상대습도    44.729379
# Name: 6326, dtype: float64
# CB 04
# 44.72937853107344
# 상대습도    44.729379
# Name: 6340, dtype: float64
# CB 03
# 46.742
# 상대습도    46.742
# Name: 6346, dtype: float64
# CB 03
# 46.742
# 상대습도    46.742
# Name: 6431, dtype: float64
# CB 02
# 52.68103448275862
# 상대습도    52.681034
# Name: 6437, dtype: float64
# CB 03
# 46.742
# 상대습도    46.742
# Name: 6438, dtype: float64
# CB 05
# 51.23962264150943
# 상대습도    51.239623
# Name: 6441, dtype: float64
# CB 04
# 44.72937853107344
# 상대습도    44.729379
# Name: 6443, dtype: float64
# CB 04
# 44.72937853107344
# 상대습도    44.729379
# Name: 6444, dtype: float64
# CB 11
# 57.83571428571428
# 상대습도    57.835714
# Name: 6446, dtype: float64
# CB 12
# 56.82
# 상대습도    56.82
# Name: 6447, dtype: float64
# CB 04
# 44.72937853107344
# 상대습도    44.729379
# Name: 6449, dtype: float64
# CB 04
# 44.72937853107345
# 상대습도    44.729379
# Name: 6450, dtype: float64
# CB 04
# 44.72937853107344
# 상대습도    44.729379
# Name: 6452, dtype: float64
# CB 03
# 46.742
# 상대습도    46.742
# Name: 6453, dtype: float64
# CB 05
# 51.23962264150943
# 상대습도    51.239623
# Name: 6454, dtype: float64
# CB 05
# 51.23962264150943
# 상대습도    51.239623
# Name: 6459, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 6470, dtype: float64
# CN 03
# 53.1087912087912
# 상대습도    53.108791
# Name: 6473, dtype: float64
# CN 03
# 53.10879120879121
# 상대습도    53.108791
# Name: 6475, dtype: float64
# CN 03
# 53.10879120879121
# 상대습도    53.108791
# Name: 6476, dtype: float64
# CN 05
# 53.54814814814815
# 상대습도    53.548148
# Name: 6484, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 6499, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 6501, dtype: float64
# CN 02
# 52.897222222222226
# 상대습도    52.897222
# Name: 6505, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 6507, dtype: float64
# CN 03
# 53.10879120879121
# 상대습도    53.108791
# Name: 6577, dtype: float64
# CN 06
# 62.234782608695646
# 상대습도    62.234783
# Name: 6631, dtype: float64
# CN 06
# 62.23478260869565
# 상대습도    62.234783
# Name: 6632, dtype: float64
# CN 03
# 53.10879120879121
# 상대습도    53.108791
# Name: 6635, dtype: float64
# CN 09
# 62.4
# 상대습도    62.4
# Name: 6636, dtype: float64
# CN 03
# 53.10879120879121
# 상대습도    53.108791
# Name: 6641, dtype: float64
# CB 03
# 46.742000000000004
# 상대습도    46.742
# Name: 6731, dtype: float64
# CB 04
# 44.72937853107345
# 상대습도    44.729379
# Name: 6734, dtype: float64
# CB 05
# 51.23962264150943
# 상대습도    51.239623
# Name: 6740, dtype: float64
# CB 03
# 46.742
# 상대습도    46.742
# Name: 6748, dtype: float64
# CB 04
# 44.72937853107344
# 상대습도    44.729379
# Name: 6749, dtype: float64
# CB 04
# 44.72937853107344
# 상대습도    44.729379
# Name: 6804, dtype: float64
# CB 04
# 44.72937853107344
# 상대습도    44.729379
# Name: 6805, dtype: float64
# CB 02
# 52.68103448275862
# 상대습도    52.681034
# Name: 6806, dtype: float64
# CB 04
# 44.72937853107345
# 상대습도    44.729379
# Name: 6807, dtype: float64
# CB 12
# 56.82
# 상대습도    56.82
# Name: 6808, dtype: float64
# CB 05
# 51.23962264150943
# 상대습도    51.239623
# Name: 6809, dtype: float64
# CB 05
# 51.239622641509435
# 상대습도    51.239623
# Name: 6810, dtype: float64
# CB 02
# 52.68103448275862
# 상대습도    52.681034
# Name: 6811, dtype: float64
# CB 03
# 46.742
# 상대습도    46.742
# Name: 6813, dtype: float64
# CB 12
# 56.82
# 상대습도    56.82
# Name: 6814, dtype: float64
# CB 05
# 51.239622641509435
# 상대습도    51.239623
# Name: 6817, dtype: float64
# CB 11
# 57.83571428571428
# 상대습도    57.835714
# Name: 6819, dtype: float64
# GG 04
# 49.437400000000004
# 상대습도    49.4374
# Name: 6824, dtype: float64
# GG 04
# 49.4374
# 상대습도    49.4374
# Name: 6836, dtype: float64
# GG 04
# 49.4374
# 상대습도    49.4374
# Name: 6841, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 6852, dtype: float64
# GW 12
# 49.81463414634146
# 상대습도    49.814634
# Name: 6910, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 6911, dtype: float64
# GW 10
# 67.30232558139535
# 상대습도    67.302326
# Name: 6915, dtype: float64
# GW 06
# 56.613402061855666
# 상대습도    56.613402
# Name: 7109, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 7111, dtype: float64
# GW 06
# 56.613402061855666
# 상대습도    56.613402
# Name: 7117, dtype: float64
# GW 05
# 49.72275132275132
# 상대습도    49.722751
# Name: 7118, dtype: float64
# GW 05
# 49.72275132275132
# 상대습도    49.722751
# Name: 7123, dtype: float64
# GW 06
# 56.613402061855666
# 상대습도    56.613402
# Name: 7125, dtype: float64
# CN 09
# 62.4
# 상대습도    62.4
# Name: 7232, dtype: float64
# GG 02
# 50.98245614035088
# 상대습도    50.982456
# Name: 7272, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 7275, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 7280, dtype: float64
# GG 03
# 51.45786163522012
# 상대습도    51.457862
# Name: 7281, dtype: float64
# GW 04
# 45.252517985611505
# 상대습도    45.252518
# Name: 7551, dtype: float64
# GW 03
# 43.5041450777202
# 상대습도    43.504145
# Name: 7558, dtype: float64
# GW 05
# 49.72275132275133
# 상대습도    49.722751
# Name: 7560, dtype: float64
# GW 02
# 47.84315789473684
# 상대습도    47.843158
# Name: 7561, dtype: float64
# GW 11
# 53.6030612244898
# 상대습도    53.603061
# Name: 7562, dtype: float64
# GW 02
# 47.84315789473684
# 상대습도    47.843158
# Name: 7563, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 7564, dtype: float64
# GW 03
# 43.5041450777202
# 상대습도    43.504145
# Name: 7594, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 7595, dtype: float64
# GW 07
# 64.08571428571429
# 상대습도    64.085714
# Name: 7596, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 7597, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 7598, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 7602, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 7608, dtype: float64
# GW 03
# 43.50414507772021
# 상대습도    43.504145
# Name: 7610, dtype: float64
# GW 12
# 49.81463414634147
# 상대습도    49.814634
# Name: 7611, dtype: float64
# GW 10
# 67.30232558139535
# 상대습도    67.302326
# Name: 7612, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 7632, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 7633, dtype: float64
# GW 05
# 49.72275132275132
# 상대습도    49.722751
# Name: 7634, dtype: float64
# GW 04
# 45.252517985611505
# 상대습도    45.252518
# Name: 7635, dtype: float64
# GW 05
# 49.72275132275132
# 상대습도    49.722751
# Name: 7636, dtype: float64
# GW 11
# 53.6030612244898
# 상대습도    53.603061
# Name: 7698, dtype: float64
# GW 05
# 49.72275132275132
# 상대습도    49.722751
# Name: 7726, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 7744, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 7749, dtype: float64
# GW 06
# 56.613402061855666
# 상대습도    56.613402
# Name: 7753, dtype: float64
# CN 03
# 53.1087912087912
# 상대습도    53.108791
# Name: 7787, dtype: float64
# GG 05
# 53.67822580645161
# 상대습도    53.678226
# Name: 7789, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 7790, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 7897, dtype: float64
# GG 02
# 50.98245614035088
# 상대습도    50.982456
# Name: 7916, dtype: float64
# GG 04
# 49.437400000000004
# 상대습도    49.4374
# Name: 7930, dtype: float64
# GG 04
# 49.437400000000004
# 상대습도    49.4374
# Name: 7931, dtype: float64
# GG 10
# 65.2090909090909
# 상대습도    65.209091
# Name: 7956, dtype: float64
# GG 05
# 53.678225806451614
# 상대습도    53.678226
# Name: 7996, dtype: float64
# GG 05
# 53.678225806451614
# 상대습도    53.678226
# Name: 7997, dtype: float64
# GG 02
# 50.982456140350884
# 상대습도    50.982456
# Name: 7998, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 8000, dtype: float64
# GG 04
# 49.4374
# 상대습도    49.4374
# Name: 8001, dtype: float64
# GG 02
# 50.98245614035087
# 상대습도    50.982456
# Name: 8002, dtype: float64
# GG 02
# 50.98245614035088
# 상대습도    50.982456
# Name: 8003, dtype: float64
# GG 04
# 49.4374
# 상대습도    49.4374
# Name: 8004, dtype: float64
# GG 05
# 53.67822580645161
# 상대습도    53.678226
# Name: 8007, dtype: float64
# GG 12
# 54.95227272727272
# 상대습도    54.952273
# Name: 8008, dtype: float64
# GG 03
# 51.45786163522012
# 상대습도    51.457862
# Name: 8009, dtype: float64
# GG 06
# 54.810810810810814
# 상대습도    54.810811
# Name: 8011, dtype: float64
# GG 02
# 50.98245614035088
# 상대습도    50.982456
# Name: 8016, dtype: float64
# GG 06
# 54.810810810810814
# 상대습도    54.810811
# Name: 8017, dtype: float64
# GG 06
# 54.810810810810814
# 상대습도    54.810811
# Name: 8018, dtype: float64
# GG 06
# 54.810810810810814
# 상대습도    54.810811
# Name: 8020, dtype: float64
# GG 04
# 49.437400000000004
# 상대습도    49.4374
# Name: 8021, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 8022, dtype: float64
# GG 05
# 53.678225806451614
# 상대습도    53.678226
# Name: 8025, dtype: float64
# GG 04
# 49.4374
# 상대습도    49.4374
# Name: 8027, dtype: float64
# GG 04
# 49.4374
# 상대습도    49.4374
# Name: 8029, dtype: float64
# GG 05
# 53.678225806451614
# 상대습도    53.678226
# Name: 8048, dtype: float64
# GG 04
# 49.437400000000004
# 상대습도    49.4374
# Name: 8052, dtype: float64
# GG 05
# 53.67822580645161
# 상대습도    53.678226
# Name: 8054, dtype: float64
# GG 05
# 53.67822580645161
# 상대습도    53.678226
# Name: 8059, dtype: float64
# GG 04
# 49.4374
# 상대습도    49.4374
# Name: 8061, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 8062, dtype: float64
# GG 04
# 49.4374
# 상대습도    49.4374
# Name: 8064, dtype: float64
# GG 11
# 59.067741935483866
# 상대습도    59.067742
# Name: 8067, dtype: float64
# GG 05
# 53.678225806451614
# 상대습도    53.678226
# Name: 8081, dtype: float64
# GG 05
# 53.678225806451614
# 상대습도    53.678226
# Name: 8082, dtype: float64
# GG 03
# 51.45786163522012
# 상대습도    51.457862
# Name: 8086, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 8094, dtype: float64
# GG 04
# 49.437400000000004
# 상대습도    49.4374
# Name: 8108, dtype: float64
# GG 05
# 53.67822580645161
# 상대습도    53.678226
# Name: 8117, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 8120, dtype: float64
# GG 11
# 59.06774193548387
# 상대습도    59.067742
# Name: 8134, dtype: float64
# GG 06
# 54.810810810810814
# 상대습도    54.810811
# Name: 8135, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 8141, dtype: float64
# GG 03
# 51.45786163522012
# 상대습도    51.457862
# Name: 8143, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 8146, dtype: float64
# GG 04
# 49.4374
# 상대습도    49.4374
# Name: 8147, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 8148, dtype: float64
# GG 11
# 59.067741935483866
# 상대습도    59.067742
# Name: 8153, dtype: float64
# GG 02
# 50.98245614035088
# 상대습도    50.982456
# Name: 8158, dtype: float64
# GW 05
# 49.72275132275133
# 상대습도    49.722751
# Name: 8260, dtype: float64
# GW 10
# 67.30232558139535
# 상대습도    67.302326
# Name: 8261, dtype: float64
# GW 03
# 43.50414507772021
# 상대습도    43.504145
# Name: 8267, dtype: float64
# GW 06
# 56.61340206185567
# 상대습도    56.613402
# Name: 8268, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 8270, dtype: float64
# GW 05
# 49.72275132275132
# 상대습도    49.722751
# Name: 8274, dtype: float64
# GW 03
# 43.5041450777202
# 상대습도    43.504145
# Name: 8277, dtype: float64
# GW 03
# 43.50414507772021
# 상대습도    43.504145
# Name: 8281, dtype: float64
# GW 01
# 46.10322580645161
# 상대습도    46.103226
# Name: 8282, dtype: float64
# GW 08
# 64.64615384615385
# 상대습도    64.646154
# Name: 8287, dtype: float64
# GW 02
# 47.84315789473684
# 상대습도    47.843158
# Name: 8288, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 8290, dtype: float64
# GW 10
# 67.30232558139535
# 상대습도    67.302326
# Name: 8291, dtype: float64
# GW 10
# 67.30232558139535
# 상대습도    67.302326
# Name: 8292, dtype: float64
# GW 03
# 43.50414507772021
# 상대습도    43.504145
# Name: 8293, dtype: float64
# CB 04
# 44.72937853107344
# 상대습도    44.729379
# Name: 8312, dtype: float64
# CB 03
# 46.742
# 상대습도    46.742
# Name: 8314, dtype: float64
# CB 04
# 44.72937853107344
# 상대습도    44.729379
# Name: 8317, dtype: float64
# GG 04
# 49.4374
# 상대습도    49.4374
# Name: 8396, dtype: float64
# GG 04
# 49.4374
# 상대습도    49.4374
# Name: 8413, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 8414, dtype: float64
# GG 04
# 49.437400000000004
# 상대습도    49.4374
# Name: 8420, dtype: float64
# GG 04
# 49.4374
# 상대습도    49.4374
# Name: 8422, dtype: float64
# GG 04
# 49.4374
# 상대습도    49.4374
# Name: 8430, dtype: float64
# GW 03
# 43.5041450777202
# 상대습도    43.504145
# Name: 8468, dtype: float64
# GW 06
# 56.61340206185567
# 상대습도    56.613402
# Name: 8484, dtype: float64
# GW 04
# 45.252517985611505
# 상대습도    45.252518
# Name: 8497, dtype: float64
# GW 12
# 49.81463414634146
# 상대습도    49.814634
# Name: 8514, dtype: float64
# GW 02
# 47.84315789473684
# 상대습도    47.843158
# Name: 8523, dtype: float64
# GW 02
# 47.84315789473684
# 상대습도    47.843158
# Name: 8524, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 8529, dtype: float64
# GW 05
# 49.72275132275132
# 상대습도    49.722751
# Name: 8530, dtype: float64
# GW 05
# 49.72275132275132
# 상대습도    49.722751
# Name: 8531, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 8532, dtype: float64
# GW 12
# 49.81463414634146
# 상대습도    49.814634
# Name: 8533, dtype: float64
# GW 02
# 47.84315789473685
# 상대습도    47.843158
# Name: 8534, dtype: float64
# GW 03
# 43.5041450777202
# 상대습도    43.504145
# Name: 8535, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 8664, dtype: float64
# GG 09
# 61.87692307692307
# 상대습도    61.876923
# Name: 8707, dtype: float64
# GG 03
# 51.45786163522012
# 상대습도    51.457862
# Name: 8710, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 8720, dtype: float64
# GG 06
# 54.810810810810814
# 상대습도    54.810811
# Name: 8725, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 8727, dtype: float64
# GG 04
# 49.437400000000004
# 상대습도    49.4374
# Name: 8747, dtype: float64
# GG 11
# 59.06774193548387
# 상대습도    59.067742
# Name: 8748, dtype: float64
# GG 12
# 54.95227272727273
# 상대습도    54.952273
# Name: 8749, dtype: float64
# GG 05
# 53.678225806451614
# 상대습도    53.678226
# Name: 8750, dtype: float64
# GG 04
# 49.4374
# 상대습도    49.4374
# Name: 8751, dtype: float64
# GG 05
# 53.678225806451614
# 상대습도    53.678226
# Name: 8924, dtype: float64
# GG 04
# 49.4374
# 상대습도    49.4374
# Name: 8926, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 8927, dtype: float64
# GG 04
# 49.437400000000004
# 상대습도    49.4374
# Name: 8928, dtype: float64
# GG 04
# 49.4374
# 상대습도    49.4374
# Name: 8930, dtype: float64
# GG 04
# 49.4374
# 상대습도    49.4374
# Name: 8931, dtype: float64
# GG 11
# 59.06774193548387
# 상대습도    59.067742
# Name: 8934, dtype: float64
# GG 02
# 50.98245614035088
# 상대습도    50.982456
# Name: 8935, dtype: float64
# GG 03
# 51.45786163522012
# 상대습도    51.457862
# Name: 8937, dtype: float64
# GG 04
# 49.437400000000004
# 상대습도    49.4374
# Name: 8995, dtype: float64
# GG 11
# 59.067741935483866
# 상대습도    59.067742
# Name: 8996, dtype: float64
# GG 04
# 49.4374
# 상대습도    49.4374
# Name: 9072, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 9115, dtype: float64
# CN 04
# 50.586692015209124
# 상대습도    50.586692
# Name: 9118, dtype: float64
# CN 03
# 53.1087912087912
# 상대습도    53.108791
# Name: 9119, dtype: float64
# CN 03
# 53.10879120879121
# 상대습도    53.108791
# Name: 9121, dtype: float64
# CN 02
# 52.89722222222222
# 상대습도    52.897222
# Name: 9122, dtype: float64
# GG 11
# 59.06774193548387
# 상대습도    59.067742
# Name: 9165, dtype: float64
# GG 04
# 49.4374
# 상대습도    49.4374
# Name: 9174, dtype: float64
# GG 02
# 50.98245614035088
# 상대습도    50.982456
# Name: 9185, dtype: float64
# GG 03
# 51.45786163522013
# 상대습도    51.457862
# Name: 9277, dtype: float64
# GG 02
# 50.982456140350884
# 상대습도    50.982456
# Name: 9283, dtype: float64
# GW 03
# 43.50414507772021
# 상대습도    43.504145
# Name: 9727, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 9729, dtype: float64
# GW 05
# 49.72275132275132
# 상대습도    49.722751
# Name: 9730, dtype: float64
# GW 05
# 49.72275132275133
# 상대습도    49.722751
# Name: 9731, dtype: float64
# GW 11
# 53.60306122448979
# 상대습도    53.603061
# Name: 9732, dtype: float64
# GW 03
# 43.5041450777202
# 상대습도    43.504145
# Name: 9733, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 9760, dtype: float64
# GW 01
# 46.10322580645161
# 상대습도    46.103226
# Name: 9762, dtype: float64
# GW 11
# 53.6030612244898
# 상대습도    53.603061
# Name: 9763, dtype: float64
# GW 08
# 64.64615384615385
# 상대습도    64.646154
# Name: 9764, dtype: float64
# GW 02
# 47.84315789473684
# 상대습도    47.843158
# Name: 9767, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 9769, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 9770, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 9771, dtype: float64
# GW 02
# 47.84315789473684
# 상대습도    47.843158
# Name: 9772, dtype: float64
# GW 04
# 45.25251798561151
# 상대습도    45.252518
# Name: 9773, dtype: float64
# GW 05
# 49.72275132275132
# 상대습도    49.722751
# Name: 9774, dtype: float64
# JB 05
# 53.91694915254237
# 상대습도    53.916949
# Name: 9855, dtype: float64
# JB 04
# 52.162433862433865
# 상대습도    52.162434
# Name: 9857, dtype: float64
# KB 04
# 43.91492957746479
# 상대습도    43.91493
# Name: 9878, dtype: float64
# KB 02
# 45.3253164556962
# 상대습도    45.325316
# Name: 9882, dtype: float64
# KB 03
# 44.0175355450237
# 상대습도    44.017536
# Name: 9884, dtype: float64
# KB 11
# 53.641764705882345
# 상대습도    53.641765
# Name: 9886, dtype: float64
# KB 03
# 44.0175355450237
# 상대습도    44.017536
# Name: 9887, dtype: float64
# KB 02
# 45.3253164556962
# 상대습도    45.325316
# Name: 9889, dtype: float64
# KB 04
# 43.91492957746479
# 상대습도    43.91493
# Name: 9908, dtype: float64
# KB 11
# 53.641764705882345
# 상대습도    53.641765
# Name: 9914, dtype: float64
# GW 05
# 49.72275132275132
# 상대습도    49.722751
# Name: 9938, dtype: float64
# JN 10
# 68.32666666666667
# 상대습도    68.326667
# Name: 9962, dtype: float64
# JN 02
# 53.58527607361963
# 상대습도    53.585276
# Name: 9963, dtype: float64
# JN 02
# 53.58527607361963
# 상대습도    53.585276
# Name: 9964, dtype: float64
# JN 12
# 57.026153846153846
# 상대습도    57.026154
# Name: 9965, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 9966, dtype: float64
# JN 03
# 54.329220779220776
# 상대습도    54.329221
# Name: 9972, dtype: float64
# JN 04
# 53.060483870967744
# 상대습도    53.060484
# Name: 9973, dtype: float64
# JN 02
# 53.58527607361964
# 상대습도    53.585276
# Name: 9974, dtype: float64
# JN 03
# 54.32922077922078
# 상대습도    54.329221
# Name: 9975, dtype: float64
# JN 02
# 53.58527607361964
# 상대습도    53.585276
# Name: 9976, dtype: float64
# JN 09
# 65.72
# 상대습도    65.72
# Name: 9977, dtype: float64
# JN 02
# 53.585276073619625
# 상대습도    53.585276
# Name: 9978, dtype: float64
# KB 04
# 38.77849686760563
# 실효습도    38.778497
# Name: 5, dtype: float64
# GG 05
# 46.32024225
# 실효습도    46.320242
# Name: 65, dtype: float64
# KN 11
# 43.6973969068323
# 실효습도    43.697397
# Name: 458, dtype: float64
# KN 01
# 35.47350658163265
# 실효습도    35.473507
# Name: 548, dtype: float64
# KN 04
# 42.180533630769226
# 실효습도    42.180534
# Name: 627, dtype: float64
# KN 05
# 46.68668772815534
# 실효습도    46.686688
# Name: 688, dtype: float64
# KN 10
# 50.354642704918035
# 실효습도    50.354643
# Name: 703, dtype: float64
# KN 04
# 42.18053363076923
# 실효습도    42.180534
# Name: 706, dtype: float64
# KN 02
# 36.35475092675159
# 실효습도    36.354751
# Name: 707, dtype: float64
# JN 03
# 47.14560255194805
# 실효습도    47.145603
# Name: 709, dtype: float64
# KN 02
# 36.35475092675159
# 실효습도    36.354751
# Name: 711, dtype: float64
# KN 01
# 35.47350658163265
# 실효습도    35.473507
# Name: 716, dtype: float64
# KN 04
# 42.18053363076923
# 실효습도    42.180534
# Name: 755, dtype: float64
# KN 05
# 46.68668772815534
# 실효습도    46.686688
# Name: 777, dtype: float64
# KN 04
# 42.18053363076923
# 실효습도    42.180534
# Name: 786, dtype: float64
# KN 10
# 50.35464270491803
# 실효습도    50.354643
# Name: 787, dtype: float64
# KN 11
# 43.6973969068323
# 실효습도    43.697397
# Name: 857, dtype: float64
# KN 12
# 38.98746393333333
# 실효습도    38.987464
# Name: 888, dtype: float64
# KN 05
# 46.68668772815534
# 실효습도    46.686688
# Name: 917, dtype: float64
# KN 12
# 38.98746393333333
# 실효습도    38.987464
# Name: 922, dtype: float64
# KN 03
# 40.94012338291139
# 실효습도    40.940123
# Name: 924, dtype: float64
# KN 12
# 38.98746393333334
# 실효습도    38.987464
# Name: 927, dtype: float64
# KN 02
# 36.35475092675159
# 실효습도    36.354751
# Name: 945, dtype: float64
# KN 02
# 36.35475092675159
# 실효습도    36.354751
# Name: 956, dtype: float64
# KN 02
# 36.35475092675159
# 실효습도    36.354751
# Name: 990, dtype: float64
# KN 05
# 46.686687728155334
# 실효습도    46.686688
# Name: 1001, dtype: float64
# KN 01
# 35.47350658163265
# 실효습도    35.473507
# Name: 1003, dtype: float64
# KN 02
# 36.35475092675159
# 실효습도    36.354751
# Name: 1018, dtype: float64
# KN 04
# 42.180533630769226
# 실효습도    42.180534
# Name: 1019, dtype: float64
# KN 11
# 43.697396906832296
# 실효습도    43.697397
# Name: 1035, dtype: float64
# KN 04
# 42.18053363076923
# 실효습도    42.180534
# Name: 1036, dtype: float64
# KN 02
# 36.35475092675159
# 실효습도    36.354751
# Name: 1037, dtype: float64
# KN 04
# 42.18053363076923
# 실효습도    42.180534
# Name: 1043, dtype: float64
# KN 04
# 42.180533630769226
# 실효습도    42.180534
# Name: 1294, dtype: float64
# KN 01
# 35.473506581632655
# 실효습도    35.473507
# Name: 1307, dtype: float64
# JN 02
# 46.568112846625766
# 실효습도    46.568113
# Name: 1380, dtype: float64
# KN 04
# 42.18053363076923
# 실효습도    42.180534
# Name: 1382, dtype: float64
# KN 11
# 43.697396906832296
# 실효습도    43.697397
# Name: 1383, dtype: float64
# KN 01
# 35.473506581632655
# 실효습도    35.473507
# Name: 1384, dtype: float64
# JN 11
# 50.6697103255814
# 실효습도    50.66971
# Name: 1386, dtype: float64
# KN 11
# 43.697396906832296
# 실효습도    43.697397
# Name: 1387, dtype: float64
# KN 03
# 40.940123382911395
# 실효습도    40.940123
# Name: 1388, dtype: float64
# KN 01
# 35.473506581632655
# 실효습도    35.473507
# Name: 1390, dtype: float64
# KN 04
# 42.18053363076923
# 실효습도    42.180534
# Name: 1395, dtype: float64
# KN 02
# 36.35475092675159
# 실효습도    36.354751
# Name: 1398, dtype: float64
# KN 02
# 36.35475092675159
# 실효습도    36.354751
# Name: 1426, dtype: float64
# KN 10
# 50.354642704918035
# 실효습도    50.354643
# Name: 1431, dtype: float64
# KN 05
# 46.686687728155334
# 실효습도    46.686688
# Name: 1432, dtype: float64
# KN 01
# 35.473506581632655
# 실효습도    35.473507
# Name: 1449, dtype: float64
# KN 03
# 40.94012338291139
# 실효습도    40.940123
# Name: 1453, dtype: float64
# KN 03
# 40.940123382911395
# 실효습도    40.940123
# Name: 1454, dtype: float64
# KN 05
# 46.68668772815534
# 실효습도    46.686688
# Name: 1563, dtype: float64
# KN 04
# 42.180533630769226
# 실효습도    42.180534
# Name: 1568, dtype: float64
# JN 12
# 48.66534803076923
# 실효습도    48.665348
# Name: 1745, dtype: float64
# JN 11
# 50.6697103255814
# 실효습도    50.66971
# Name: 1754, dtype: float64
# JN 03
# 47.14560255194805
# 실효습도    47.145603
# Name: 1758, dtype: float64
# JN 03
# 47.14560255194805
# 실효습도    47.145603
# Name: 1759, dtype: float64
# JN 03
# 47.14560255194805
# 실효습도    47.145603
# Name: 1761, dtype: float64
# JN 04
# 46.32476034146342
# 실효습도    46.32476
# Name: 1762, dtype: float64
# JN 04
# 46.32476034146342
# 실효습도    46.32476
# Name: 1764, dtype: float64
# KB 05
# 44.05110983870968
# 실효습도    44.05111
# Name: 1867, dtype: float64
# KB 03
# 38.91900073222748
# 실효습도    38.919001
# Name: 1911, dtype: float64
# KB 03
# 38.91900073222749
# ...
# Name: 6507, dtype: float64
# CN 03
# 46.12755543956044
# 실효습도    46.127555
# Name: 6577, dtype: float64
# CN 06
# 53.403778304347824
# 실효습도    53.403778
# Name: 6631, dtype: float64
# CN 06
# 53.403778304347824
# 실효습도    53.403778
# Name: 6632, dtype: float64
# CN 03
# 46.12755543956044
# 실효습도    46.127555
# Name: 6635, dtype: float64
# CN 09
# 54.445745045454544
# 실효습도    54.445745
# Name: 6636, dtype: float64
# CN 03
# 46.127555439560446
# 실효습도    46.127555
# Name: 6641, dtype: float64
# CB 03
# 41.375532879999994
# 실효습도    41.375533
# Name: 6731, dtype: float64
# CB 04
# 39.77873430681818
# 실효습도    39.778734
# Name: 6734, dtype: float64
# CB 05
# 42.789024
# 실효습도    42.789024
# Name: 6740, dtype: float64
# CB 03
# 41.37553288
# 실효습도    41.375533
# Name: 6748, dtype: float64
# CB 04
# 39.77873430681818
# 실효습도    39.778734
# Name: 6749, dtype: float64
# CB 04
# 39.77873430681818
# 실효습도    39.778734
# Name: 6804, dtype: float64
# CB 04
# 39.77873430681818
# 실효습도    39.778734
# Name: 6805, dtype: float64
# CB 02
# 44.57949010344828
# 실효습도    44.57949
# Name: 6806, dtype: float64
# CB 04
# 39.77873430681818
# 실효습도    39.778734
# Name: 6807, dtype: float64
# CB 12
# 47.1139386
# 실효습도    47.113939
# Name: 6808, dtype: float64
# CB 05
# 42.789024000000005
# 실효습도    42.789024
# Name: 6809, dtype: float64
# CB 05
# 42.789024
# 실효습도    42.789024
# Name: 6810, dtype: float64
# CB 02
# 44.57949010344828
# 실효습도    44.57949
# Name: 6811, dtype: float64
# CB 03
# 41.37553288
# 실효습도    41.375533
# Name: 6813, dtype: float64
# CB 12
# 47.1139386
# 실효습도    47.113939
# Name: 6814, dtype: float64
# CB 05
# 42.789024
# 실효습도    42.789024
# Name: 6817, dtype: float64
# CB 11
# 50.98587128571428
# 실효습도    50.985871
# Name: 6819, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 6824, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 6836, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 6841, dtype: float64
# GG 03
# 44.89685813836478
# 실효습도    44.896858
# Name: 6852, dtype: float64
# GW 12
# 42.46684426829268
# 실효습도    42.466844
# Name: 6910, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 6911, dtype: float64
# GW 10
# 56.29718051162791
# 실효습도    56.297181
# Name: 6915, dtype: float64
# GW 06
# 47.997971721649485
# 실효습도    47.997972
# Name: 7109, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 7111, dtype: float64
# GW 06
# 47.99797172164948
# 실효습도    47.997972
# Name: 7117, dtype: float64
# GW 05
# 43.852405069148936
# 실효습도    43.852405
# Name: 7118, dtype: float64
# GW 05
# 43.85240506914893
# 실효습도    43.852405
# Name: 7123, dtype: float64
# GW 06
# 47.997971721649485
# 실효습도    47.997972
# Name: 7125, dtype: float64
# CN 09
# 54.44574504545455
# 실효습도    54.445745
# Name: 7232, dtype: float64
# GG 02
# 45.30814942105263
# 실효습도    45.308149
# Name: 7272, dtype: float64
# GG 03
# 44.89685813836478
# 실효습도    44.896858
# Name: 7275, dtype: float64
# GG 03
# 44.89685813836478
# 실효습도    44.896858
# Name: 7280, dtype: float64
# GG 03
# 44.896858138364784
# 실효습도    44.896858
# Name: 7281, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 7551, dtype: float64
# GW 03
# 39.38478217616581
# 실효습도    39.384782
# Name: 7558, dtype: float64
# GW 05
# 43.852405069148936
# 실효습도    43.852405
# Name: 7560, dtype: float64
# GW 02
# 40.01346498947368
# 실효습도    40.013465
# Name: 7561, dtype: float64
# GW 11
# 45.07698101020408
# 실효습도    45.076981
# Name: 7562, dtype: float64
# GW 02
# 40.01346498947368
# 실효습도    40.013465
# Name: 7563, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 7564, dtype: float64
# GW 03
# 39.3847821761658
# 실효습도    39.384782
# Name: 7594, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 7595, dtype: float64
# GW 07
# 53.83028228571428
# 실효습도    53.830282
# Name: 7596, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 7597, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 7598, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 7602, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 7608, dtype: float64
# GW 03
# 39.3847821761658
# 실효습도    39.384782
# Name: 7610, dtype: float64
# GW 12
# 42.46684426829268
# 실효습도    42.466844
# Name: 7611, dtype: float64
# GW 10
# 56.2971805116279
# 실효습도    56.297181
# Name: 7612, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 7632, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 7633, dtype: float64
# GW 05
# 43.852405069148936
# 실효습도    43.852405
# Name: 7634, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 7635, dtype: float64
# GW 05
# 43.852405069148936
# 실효습도    43.852405
# Name: 7636, dtype: float64
# GW 01
# 38.7615379
# 실효습도    38.761538
# Name: 7644, dtype: float64
# GW 11
# 45.076981010204086
# 실효습도    45.076981
# Name: 7698, dtype: float64
# GW 05
# 43.852405069148936
# 실효습도    43.852405
# Name: 7726, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 7744, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 7749, dtype: float64
# GW 06
# 47.997971721649485
# 실효습도    47.997972
# Name: 7753, dtype: float64
# CN 03
# 46.12755543956044
# 실효습도    46.127555
# Name: 7787, dtype: float64
# GG 05
# 46.32024225
# 실효습도    46.320242
# Name: 7789, dtype: float64
# GG 03
# 44.89685813836478
# 실효습도    44.896858
# Name: 7790, dtype: float64
# GG 03
# 44.89685813836478
# 실효습도    44.896858
# Name: 7897, dtype: float64
# GG 02
# 45.30814942105263
# 실효습도    45.308149
# Name: 7916, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 7930, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 7931, dtype: float64
# GG 10
# 54.16894609090909
# 실효습도    54.168946
# Name: 7956, dtype: float64
# GG 05
# 46.32024225
# 실효습도    46.320242
# Name: 7996, dtype: float64
# GG 05
# 46.32024225
# 실효습도    46.320242
# Name: 7997, dtype: float64
# GG 02
# 45.30814942105263
# 실효습도    45.308149
# Name: 7998, dtype: float64
# GG 03
# 44.89685813836478
# 실효습도    44.896858
# Name: 8000, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 8001, dtype: float64
# GG 02
# 45.30814942105263
# 실효습도    45.308149
# Name: 8002, dtype: float64
# GG 02
# 45.30814942105263
# 실효습도    45.308149
# Name: 8003, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 8004, dtype: float64
# GG 05
# 46.32024225
# 실효습도    46.320242
# Name: 8007, dtype: float64
# GG 12
# 47.99226651136364
# 실효습도    47.992267
# Name: 8008, dtype: float64
# GG 03
# 44.89685813836478
# 실효습도    44.896858
# Name: 8009, dtype: float64
# GG 06
# 46.89588402739726
# 실효습도    46.895884
# Name: 8011, dtype: float64
# GG 02
# 45.30814942105263
# 실효습도    45.308149
# Name: 8016, dtype: float64
# GG 06
# 46.89588402739726
# 실효습도    46.895884
# Name: 8017, dtype: float64
# GG 06
# 46.89588402739726
# 실효습도    46.895884
# Name: 8018, dtype: float64
# GG 06
# 46.895884027397265
# 실효습도    46.895884
# Name: 8020, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 8021, dtype: float64
# GG 03
# 44.896858138364784
# 실효습도    44.896858
# Name: 8022, dtype: float64
# GG 05
# 46.32024225
# 실효습도    46.320242
# Name: 8025, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 8027, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 8029, dtype: float64
# GG 05
# 46.32024225
# 실효습도    46.320242
# Name: 8048, dtype: float64
# GG 04
# 43.78468839000001
# 실효습도    43.784688
# Name: 8052, dtype: float64
# GG 05
# 46.32024225
# 실효습도    46.320242
# Name: 8054, dtype: float64
# GG 05
# 46.32024225
# 실효습도    46.320242
# Name: 8059, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 8061, dtype: float64
# GG 03
# 44.89685813836478
# 실효습도    44.896858
# Name: 8062, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 8064, dtype: float64
# GG 11
# 51.06232854838709
# 실효습도    51.062329
# Name: 8067, dtype: float64
# GG 05
# 46.32024225
# 실효습도    46.320242
# Name: 8081, dtype: float64
# GG 05
# 46.32024225
# 실효습도    46.320242
# Name: 8082, dtype: float64
# GG 03
# 44.89685813836478
# 실효습도    44.896858
# Name: 8086, dtype: float64
# GG 03
# 44.89685813836478
# 실효습도    44.896858
# Name: 8094, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 8108, dtype: float64
# GG 05
# 46.32024225
# 실효습도    46.320242
# Name: 8117, dtype: float64
# GG 03
# 44.89685813836478
# 실효습도    44.896858
# Name: 8120, dtype: float64
# GG 11
# 51.06232854838709
# 실효습도    51.062329
# Name: 8134, dtype: float64
# GG 06
# 46.895884027397265
# 실효습도    46.895884
# Name: 8135, dtype: float64
# GG 03
# 44.896858138364784
# 실효습도    44.896858
# Name: 8141, dtype: float64
# GG 03
# 44.89685813836478
# 실효습도    44.896858
# Name: 8143, dtype: float64
# GG 03
# 44.896858138364784
# 실효습도    44.896858
# Name: 8146, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 8147, dtype: float64
# GG 03
# 44.89685813836478
# 실효습도    44.896858
# Name: 8148, dtype: float64
# GG 11
# 51.06232854838709
# 실효습도    51.062329
# Name: 8153, dtype: float64
# GG 02
# 45.30814942105263
# 실효습도    45.308149
# Name: 8158, dtype: float64
# GW 05
# 43.85240506914894
# 실효습도    43.852405
# Name: 8260, dtype: float64
# GW 10
# 56.29718051162791
# 실효습도    56.297181
# Name: 8261, dtype: float64
# GW 03
# 39.38478217616581
# 실효습도    39.384782
# Name: 8267, dtype: float64
# GW 06
# 47.997971721649485
# 실효습도    47.997972
# Name: 8268, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 8270, dtype: float64
# GW 05
# 43.852405069148936
# 실효습도    43.852405
# Name: 8274, dtype: float64
# GW 03
# 39.38478217616581
# 실효습도    39.384782
# Name: 8277, dtype: float64
# GW 03
# 39.3847821761658
# 실효습도    39.384782
# Name: 8281, dtype: float64
# GW 01
# 38.7615379
# 실효습도    38.761538
# Name: 8282, dtype: float64
# GW 08
# 54.73812392307692
# 실효습도    54.738124
# Name: 8287, dtype: float64
# GW 02
# 40.01346498947368
# 실효습도    40.013465
# Name: 8288, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 8290, dtype: float64
# GW 10
# 56.29718051162791
# 실효습도    56.297181
# Name: 8291, dtype: float64
# GW 10
# 56.29718051162791
# 실효습도    56.297181
# Name: 8292, dtype: float64
# GW 03
# 39.3847821761658
# 실효습도    39.384782
# Name: 8293, dtype: float64
# CB 04
# 39.77873430681819
# 실효습도    39.778734
# Name: 8312, dtype: float64
# CB 03
# 41.37553288
# 실효습도    41.375533
# Name: 8314, dtype: float64
# CB 04
# 39.77873430681818
# 실효습도    39.778734
# Name: 8317, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 8396, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 8413, dtype: float64
# GG 03
# 44.89685813836478
# 실효습도    44.896858
# Name: 8414, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 8420, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 8422, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 8430, dtype: float64
# GW 03
# 39.38478217616581
# 실효습도    39.384782
# Name: 8468, dtype: float64
# GW 06
# 47.99797172164948
# 실효습도    47.997972
# Name: 8484, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 8497, dtype: float64
# GW 05
# 43.852405069148936
# 실효습도    43.852405
# Name: 8510, dtype: float64
# GW 12
# 42.46684426829268
# 실효습도    42.466844
# Name: 8514, dtype: float64
# GW 02
# 40.01346498947369
# 실효습도    40.013465
# Name: 8523, dtype: float64
# GW 02
# 40.01346498947368
# 실효습도    40.013465
# Name: 8524, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 8529, dtype: float64
# GW 05
# 43.852405069148936
# 실효습도    43.852405
# Name: 8530, dtype: float64
# GW 05
# 43.85240506914893
# 실효습도    43.852405
# Name: 8531, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 8532, dtype: float64
# GW 12
# 42.46684426829268
# 실효습도    42.466844
# Name: 8533, dtype: float64
# GW 02
# 40.01346498947368
# 실효습도    40.013465
# Name: 8534, dtype: float64
# GW 03
# 39.38478217616581
# 실효습도    39.384782
# Name: 8535, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 8664, dtype: float64
# GG 09
# 54.78111784615385
# 실효습도    54.781118
# Name: 8707, dtype: float64
# GG 03
# 44.896858138364784
# 실효습도    44.896858
# Name: 8710, dtype: float64
# GG 03
# 44.89685813836478
# 실효습도    44.896858
# Name: 8720, dtype: float64
# GG 06
# 46.89588402739726
# 실효습도    46.895884
# Name: 8725, dtype: float64
# GG 03
# 44.896858138364784
# 실효습도    44.896858
# Name: 8727, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 8747, dtype: float64
# GG 11
# 51.06232854838709
# 실효습도    51.062329
# Name: 8748, dtype: float64
# GG 12
# 47.99226651136364
# 실효습도    47.992267
# Name: 8749, dtype: float64
# GG 05
# 46.32024225
# 실효습도    46.320242
# Name: 8750, dtype: float64
# GG 04
# 43.78468839000001
# 실효습도    43.784688
# Name: 8751, dtype: float64
# GG 05
# 46.32024225
# 실효습도    46.320242
# Name: 8924, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 8926, dtype: float64
# GG 03
# 44.89685813836478
# 실효습도    44.896858
# Name: 8927, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 8928, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 8930, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 8931, dtype: float64
# GG 11
# 51.06232854838709
# 실효습도    51.062329
# Name: 8934, dtype: float64
# GG 02
# 45.30814942105263
# 실효습도    45.308149
# Name: 8935, dtype: float64
# GG 03
# 44.89685813836478
# 실효습도    44.896858
# Name: 8937, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 8995, dtype: float64
# GG 11
# 51.06232854838709
# 실효습도    51.062329
# Name: 8996, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 9072, dtype: float64
# GG 03
# 44.896858138364784
# 실효습도    44.896858
# Name: 9115, dtype: float64
# CN 04
# 44.80069584732824
# 실효습도    44.800696
# Name: 9118, dtype: float64
# CN 03
# 46.12755543956044
# 실효습도    46.127555
# Name: 9119, dtype: float64
# CN 03
# 46.12755543956044
# 실효습도    46.127555
# Name: 9121, dtype: float64
# CN 02
# 46.996696375
# 실효습도    46.996696
# Name: 9122, dtype: float64
# GG 11
# 51.06232854838709
# 실효습도    51.062329
# Name: 9165, dtype: float64
# GG 04
# 43.78468839
# 실효습도    43.784688
# Name: 9174, dtype: float64
# GG 02
# 45.30814942105263
# 실효습도    45.308149
# Name: 9185, dtype: float64
# GG 06
# 46.89588402739726
# 실효습도    46.895884
# Name: 9276, dtype: float64
# GG 03
# 44.89685813836478
# 실효습도    44.896858
# Name: 9277, dtype: float64
# GG 02
# 45.30814942105263
# 실효습도    45.308149
# Name: 9283, dtype: float64
# JB 04
# 45.1508648342246
# 실효습도    45.150865
# Name: 9615, dtype: float64
# GW 03
# 39.3847821761658
# 실효습도    39.384782
# Name: 9727, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 9729, dtype: float64
# GW 05
# 43.852405069148936
# 실효습도    43.852405
# Name: 9730, dtype: float64
# GW 05
# 43.852405069148936
# 실효습도    43.852405
# Name: 9731, dtype: float64
# GW 11
# 45.07698101020408
# 실효습도    45.076981
# Name: 9732, dtype: float64
# GW 03
# 39.3847821761658
# 실효습도    39.384782
# Name: 9733, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 9760, dtype: float64
# GW 01
# 38.7615379
# 실효습도    38.761538
# Name: 9762, dtype: float64
# GW 11
# 45.07698101020408
# 실효습도    45.076981
# Name: 9763, dtype: float64
# GW 08
# 54.73812392307692
# 실효습도    54.738124
# Name: 9764, dtype: float64
# GW 02
# 40.01346498947368
# 실효습도    40.013465
# Name: 9767, dtype: float64
# GW 04
# 40.07205963669065
# 실효습도    40.07206
# Name: 9769, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 9770, dtype: float64
# GW 04
# 40.072059636690646
# 실효습도    40.07206
# Name: 9771, dtype: float64
# GW 02
# 40.01346498947369
# 실효습도    40.013465
# Name: 9772, dtype: float64
# GW 04
# 40.07205963669065
# 실효습도    40.07206
# Name: 9773, dtype: float64
# GW 05
# 43.852405069148936
# 실효습도    43.852405
# Name: 9774, dtype: float64
# JB 05
# 47.02151989830509
# 실효습도    47.02152
# Name: 9855, dtype: float64
# JB 04
# 45.1508648342246
# 실효습도    45.150865
# Name: 9857, dtype: float64
# KB 04
# 38.77849686760563
# 실효습도    38.778497
# Name: 9878, dtype: float64
# KB 02
# 39.22552956962026
# 실효습도    39.22553
# Name: 9882, dtype: float64
# KB 03
# 38.91900073222749
# 실효습도    38.919001
# Name: 9884, dtype: float64
# KB 11
# 45.19798575882353
# 실효습도    45.197986
# Name: 9886, dtype: float64
# KB 03
# 38.91900073222749
# 실효습도    38.919001
# Name: 9887, dtype: float64
# KB 02
# 39.22552956962025
# 실효습도    39.22553
# Name: 9889, dtype: float64
# KB 04
# 38.77849686760563
# 실효습도    38.778497
# Name: 9908, dtype: float64
# KB 11
# 45.19798575882353
# 실효습도    45.197986
# Name: 9914, dtype: float64
# GW 05
# 43.852405069148936
# 실효습도    43.852405
# Name: 9938, dtype: float64
# JN 10
# 57.033261
# 실효습도    57.033261
# Name: 9962, dtype: float64
# JN 02
# 46.568112846625766
# 실효습도    46.568113
# Name: 9963, dtype: float64
# JN 02
# 46.568112846625766
# 실효습도    46.568113
# Name: 9964, dtype: float64
# JN 12
# 48.66534803076923
# 실효습도    48.665348
# Name: 9965, dtype: float64
# JN 04
# 46.32476034146342
# 실효습도    46.32476
# Name: 9966, dtype: float64
# JN 03
# 47.14560255194805
# 실효습도    47.145603
# Name: 9972, dtype: float64
# JN 04
# 46.32476034146342
# 실효습도    46.32476
# Name: 9973, dtype: float64
# JN 02
# 46.56811284662577
# 실효습도    46.568113
# Name: 9974, dtype: float64
# JN 03
# 47.14560255194806
# 실효습도    47.145603
# Name: 9975, dtype: float64
# JN 02
# 46.56811284662577
# 실효습도    46.568113
# Name: 9976, dtype: float64
# JN 09
# 58.3985649
# 실효습도    58.398565
# Name: 9977, dtype: float64
# JN 02
# 46.56811284662577
# 실효습도    46.568113
# Name: 9978, dtype: float64
# KN 01
# 35.473506581632655
# 실효습도    35.473507
# Name: 9989, dtype: float64
# 1309

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10011 entries, 0 to 10010
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   발생지역        10011 non-null  object
#  1   피해면적        10011 non-null  float64
#  2   평균기온(°C)    10011 non-null  float64
#  3   평균 풍속(m/s)  10011 non-null  float64
#  4   일강수량(mm)    10011 non-null  float64
#  5   상대습도        10011 non-null  float64
#  6   실효습도        10011 non-null  float64
#  7   날짜          10011 non-null  datetime64[ns]
#  8   계절          10011 non-null  object
#  9   month       10011 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(3)
# memory usage: 1.1+ MB

# %%
data['계절'].value_counts()
# Out:
# 봄     6779
# 그외    2089
# 가을    1143
# Name: 계절, dtype: int64

# %%
data.describe()
# Out:
#                피해면적      평균기온(°C)    평균 풍속(m/s)      일강수량(mm)          상대습도  \
# count  10011.000000  10011.000000  10011.000000  10011.000000  10011.000000
# mean       4.318035     -0.314382      0.019387     -0.244542     50.824441
# std      171.710795      0.804896      0.863906      0.158189     12.883880
# min        0.000000     -2.651920     -1.673767     -0.280083     10.400000
# 25%        0.030000     -0.898390     -0.547116     -0.269151     42.000000
# 50%        0.100000     -0.331327     -0.201567     -0.265740     50.500000
# 75%        0.400000      0.260873      0.325066     -0.263493     59.300000
# max    16301.980000      1.997354     11.249907      4.086121     98.100000
#
#                실효습도
# count  10011.000000
# mean      44.126488
# std        8.781532
# min       18.425328
# 25%       38.134065
# 50%       44.109117
# 75%       49.918747
# max       75.617412

# %%
data = pd.get_dummies(data = data, columns = ['계절'], prefix = '계절')

# %%
#data['계절'] = data['계절'].map({'봄': 2, '가을': 1, '그외': 0})

# %%
#data['계절'].value_counts()

# %%
data = data.rename(columns={ data.columns[9]: '가을', data.columns[10]: '여름겨울', data.columns[11]: '봄'})

# %%
data.head(2)
# Out:
#   발생지역  피해면적  평균기온(°C)  평균 풍속(m/s)  일강수량(mm)  상대습도       실효습도         날짜  \
# 0   KB  5.30  1.071246    0.118464 -0.269151  39.4  35.771319 2022-05-31
# 1   KB  0.03  0.299490   -0.138252 -0.269151  33.3  35.766492 2022-04-18
#
#   month  가을  여름겨울  봄
# 0    05   0     1  0
# 1    04   0     0  1

# %%
data.drop(['발생지역','날짜','month'],axis=1,inplace=True)

# %%
heatmap_data = data[['피해면적', '평균기온(°C)', '평균 풍속(m/s)', '일강수량(mm)', '상대습도', '실효습도', '가을',
       '여름겨울', '봄']]

# %%
#heatmap_data = data[['피해면적','상대습도', '기온', '강수량', '풍속', '실효습도','계절']]

# %%
for i in range(len(data)):
    if data['피해면적'][i]<0.1 :
        data['피해면적'][i]=1
    elif (data['피해면적'][i]>=0.1) & (data['피해면적'][i]<0.5) :
        data['피해면적'][i]=2
    elif (data['피해면적'][i]>=0.5) & (data['피해면적'][i]<5) :
        data['피해면적'][i]=3
    else :
        data['피해면적'][i]=4

# %%
data['피해면적'].value_counts()
# Out:
# 2.0    3790
# 1.0    3778
# 3.0    2159
# 4.0     284
# Name: 피해면적, dtype: int64

# %%
colormap = plt.cm.PuBu
plt.figure(figsize=(25, 20))
sns.heatmap(heatmap_data.astype(float).corr(), linewidths = 0.1, vmax = 1.0,
           square = True, cmap = colormap, linecolor = "white", annot = True, annot_kws = {"size" : 16})
# Out:
# <AxesSubplot:>

# %% [markdown]
# DATA split

# %%
#data.drop(['봄','여름겨울','가을'],axis=1,inplace=True)

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

train=data

target = train['피해면적'][:len(train)]

print(train.shape,target.shape)

train.drop(['피해면적'],axis=1,inplace=True)
# Out:
# (10011, 9) (10011,)

# %%
X_train, X_test, y_train, y_test = train_test_split(train, target, test_size=0.2,stratify=target,random_state=42) 

print(X_train.shape, X_test.shape,  y_train.shape, y_test.shape )
# Out:
# (8008, 8) (2003, 8) (8008,) (2003,)

# %% [markdown]
# # RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

model1 = RandomForestClassifier(n_estimators=100,random_state=42)
model1.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
prediction = model1.predict(X_test)
print("Accuracy is: ", accuracy_score(prediction, y_test))
acc_RF=accuracy_score(prediction, y_test)
# Out:
# Accuracy is:  0.4313529705441837

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test, prediction)
sns.heatmap(cm, annot=True, cmap="Blues", fmt='g')
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# <AxesSubplot:>
# Text(0.5, 7.222222222222195, 'Predicted Label')
# Text(32.72222222222222, 0.5, 'True Label')
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score

precision = precision_score(y_test, prediction, average=None)
recall = recall_score(y_test, prediction, average=None)

print("Precision:", precision)
print("Recall:", recall)
# Out:
# Precision: [0.48156425 0.41758242 0.30514706 0.47058824]
# Recall: [0.57010582 0.45118734 0.19212963 0.14035088]

# %%
sorted_feature_importance = model1.feature_importances_.argsort()
plt.barh(X_test.columns[sorted_feature_importance],
        model1.feature_importances_[sorted_feature_importance],
        color='turquoise')
plt.xlabel("CatBoost Feature Importance")
# Out:
# <BarContainer object of 8 artists>
# Text(0.5, 0, 'CatBoost Feature Importance')

# %% [markdown]
# # CatBoost

# %%
from catboost import CatBoostClassifier
model = CatBoostClassifier(n_estimators=100,random_state=42)
model.fit(X_train, y_train)
# Out:
# Learning rate set to 0.5
# 0:	learn: 1.2500579	total: 146ms	remaining: 14.4s
# 1:	learn: 1.1865853	total: 150ms	remaining: 7.36s
# 2:	learn: 1.1561161	total: 156ms	remaining: 5.04s
# 3:	learn: 1.1392746	total: 160ms	remaining: 3.85s
# 4:	learn: 1.1246475	total: 165ms	remaining: 3.13s
# 5:	learn: 1.1180527	total: 169ms	remaining: 2.65s
# 6:	learn: 1.1146527	total: 174ms	remaining: 2.31s
# 7:	learn: 1.1086525	total: 178ms	remaining: 2.04s
# 8:	learn: 1.1045609	total: 181ms	remaining: 1.83s
# 9:	learn: 1.1004596	total: 184ms	remaining: 1.66s
# 10:	learn: 1.0925939	total: 188ms	remaining: 1.52s
# 11:	learn: 1.0874228	total: 192ms	remaining: 1.41s
# 12:	learn: 1.0847486	total: 195ms	remaining: 1.3s
# 13:	learn: 1.0827903	total: 198ms	remaining: 1.22s
# 14:	learn: 1.0793400	total: 202ms	remaining: 1.14s
# 15:	learn: 1.0771804	total: 206ms	remaining: 1.08s
# 16:	learn: 1.0744918	total: 209ms	remaining: 1.02s
# 17:	learn: 1.0718879	total: 212ms	remaining: 966ms
# 18:	learn: 1.0696572	total: 215ms	remaining: 916ms
# 19:	learn: 1.0670336	total: 218ms	remaining: 872ms
# 20:	learn: 1.0636883	total: 221ms	remaining: 833ms
# 21:	learn: 1.0617438	total: 225ms	remaining: 796ms
# 22:	learn: 1.0567470	total: 228ms	remaining: 762ms
# 23:	learn: 1.0521618	total: 231ms	remaining: 731ms
# 24:	learn: 1.0493095	total: 233ms	remaining: 700ms
# 25:	learn: 1.0458108	total: 237ms	remaining: 673ms
# 26:	learn: 1.0436046	total: 240ms	remaining: 648ms
# 27:	learn: 1.0402757	total: 243ms	remaining: 624ms
# 28:	learn: 1.0386478	total: 246ms	remaining: 601ms
# 29:	learn: 1.0351759	total: 249ms	remaining: 580ms
# 30:	learn: 1.0327669	total: 252ms	remaining: 560ms
# 31:	learn: 1.0288221	total: 255ms	remaining: 541ms
# 32:	learn: 1.0267880	total: 258ms	remaining: 523ms
# 33:	learn: 1.0238938	total: 261ms	remaining: 507ms
# 34:	learn: 1.0201314	total: 264ms	remaining: 490ms
# 35:	learn: 1.0173890	total: 267ms	remaining: 474ms
# 36:	learn: 1.0146664	total: 270ms	remaining: 459ms
# 37:	learn: 1.0132820	total: 272ms	remaining: 444ms
# 38:	learn: 1.0117386	total: 275ms	remaining: 430ms
# 39:	learn: 1.0093653	total: 278ms	remaining: 416ms
# 40:	learn: 1.0063821	total: 280ms	remaining: 404ms
# 41:	learn: 1.0040572	total: 283ms	remaining: 391ms
# 42:	learn: 1.0010092	total: 286ms	remaining: 379ms
# 43:	learn: 0.9985523	total: 289ms	remaining: 368ms
# 44:	learn: 0.9954269	total: 292ms	remaining: 357ms
# 45:	learn: 0.9932381	total: 295ms	remaining: 346ms
# 46:	learn: 0.9915369	total: 297ms	remaining: 335ms
# 47:	learn: 0.9900797	total: 300ms	remaining: 325ms
# 48:	learn: 0.9882949	total: 303ms	remaining: 315ms
# 49:	learn: 0.9862335	total: 306ms	remaining: 306ms
# 50:	learn: 0.9850274	total: 308ms	remaining: 296ms
# 51:	learn: 0.9836324	total: 311ms	remaining: 287ms
# 52:	learn: 0.9817396	total: 314ms	remaining: 278ms
# 53:	learn: 0.9800446	total: 316ms	remaining: 269ms
# 54:	learn: 0.9787057	total: 319ms	remaining: 261ms
# 55:	learn: 0.9770920	total: 322ms	remaining: 253ms
# 56:	learn: 0.9744521	total: 325ms	remaining: 245ms
# 57:	learn: 0.9716806	total: 328ms	remaining: 237ms
# 58:	learn: 0.9698203	total: 331ms	remaining: 230ms
# 59:	learn: 0.9678518	total: 334ms	remaining: 222ms
# 60:	learn: 0.9658125	total: 337ms	remaining: 215ms
# 61:	learn: 0.9640034	total: 339ms	remaining: 208ms
# 62:	learn: 0.9621057	total: 342ms	remaining: 201ms
# 63:	learn: 0.9596895	total: 345ms	remaining: 194ms
# 64:	learn: 0.9575204	total: 347ms	remaining: 187ms
# 65:	learn: 0.9561741	total: 350ms	remaining: 180ms
# 66:	learn: 0.9541460	total: 353ms	remaining: 174ms
# 67:	learn: 0.9518849	total: 355ms	remaining: 167ms
# 68:	learn: 0.9496323	total: 358ms	remaining: 161ms
# 69:	learn: 0.9479999	total: 361ms	remaining: 155ms
# 70:	learn: 0.9467406	total: 364ms	remaining: 149ms
# 71:	learn: 0.9450107	total: 367ms	remaining: 143ms
# 72:	learn: 0.9427507	total: 371ms	remaining: 137ms
# 73:	learn: 0.9409115	total: 373ms	remaining: 131ms
# 74:	learn: 0.9389534	total: 376ms	remaining: 125ms
# 75:	learn: 0.9372989	total: 379ms	remaining: 120ms
# 76:	learn: 0.9359184	total: 382ms	remaining: 114ms
# 77:	learn: 0.9339493	total: 385ms	remaining: 109ms
# 78:	learn: 0.9322626	total: 388ms	remaining: 103ms
# 79:	learn: 0.9308086	total: 390ms	remaining: 97.6ms
# 80:	learn: 0.9290868	total: 393ms	remaining: 92.2ms
# 81:	learn: 0.9277606	total: 396ms	remaining: 86.9ms
# 82:	learn: 0.9267506	total: 399ms	remaining: 81.6ms
# 83:	learn: 0.9249005	total: 402ms	remaining: 76.5ms
# 84:	learn: 0.9230085	total: 404ms	remaining: 71.4ms
# 85:	learn: 0.9204654	total: 407ms	remaining: 66.2ms
# 86:	learn: 0.9192130	total: 410ms	remaining: 61.2ms
# 87:	learn: 0.9166970	total: 413ms	remaining: 56.3ms
# 88:	learn: 0.9151733	total: 416ms	remaining: 51.4ms
# 89:	learn: 0.9136484	total: 418ms	remaining: 46.5ms
# 90:	learn: 0.9111335	total: 421ms	remaining: 41.7ms
# 91:	learn: 0.9093886	total: 424ms	remaining: 36.9ms
# 92:	learn: 0.9080230	total: 427ms	remaining: 32.1ms
# 93:	learn: 0.9057357	total: 429ms	remaining: 27.4ms
# 94:	learn: 0.9038171	total: 432ms	remaining: 22.8ms
# 95:	learn: 0.9020959	total: 435ms	remaining: 18.1ms
# 96:	learn: 0.9000909	total: 438ms	remaining: 13.5ms
# 97:	learn: 0.8986581	total: 440ms	remaining: 8.98ms
# 98:	learn: 0.8971606	total: 443ms	remaining: 4.47ms
# 99:	learn: 0.8959690	total: 446ms	remaining: 0us

# %%
prediction = model.predict(X_test)
print("Accuracy is: ", accuracy_score(prediction, y_test))
acc_RF=accuracy_score(prediction, y_test)
# Out:
# Accuracy is:  0.42286570144782826

# %%
sorted_feature_importance = model.feature_importances_.argsort()
plt.barh(X_test.columns[sorted_feature_importance],
        model.feature_importances_[sorted_feature_importance],
        color='turquoise')
plt.xlabel("CatBoost Feature Importance")
# Out:
# <BarContainer object of 8 artists>
# Text(0.5, 0, 'CatBoost Feature Importance')

# %%
cm = confusion_matrix(y_test, prediction)
sns.heatmap(cm, annot=True, cmap="Blues", fmt='g')
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# <AxesSubplot:>
# Text(0.5, 7.222222222222195, 'Predicted Label')
# Text(32.72222222222222, 0.5, 'True Label')
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
precision = precision_score(y_test, prediction, average=None)
recall = recall_score(y_test, prediction, average=None)

print("Precision:", precision)
print("Recall:", recall)
# Out:
# Precision: [0.46349942 0.41048035 0.30733945 0.66666667]
# Recall: [0.52910053 0.49604222 0.15509259 0.07017544]

# %% [markdown]
# .

# %% [markdown]
# .
